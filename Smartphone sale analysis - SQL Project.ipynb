# %% [markdown]
# ## **Smartphone Sales Analysis: From Data Cleanup to Complex SQL Interrogation**
#
# Step into the world of smartphone sales analysis alongside Mark, the data aficionado, in our project, "Smartphone Sales Analysis: From Data Cleanup to Complex SQL Interrogation." This project, a fusion of Python's data-cleaning prowess and SQL's analytical might, is a journey through two pivotal modules aimed at unraveling the intricate landscape of smartphone sales.
#
# In Module 1, Python takes the reins, meticulously refining the dataset by tackling null values, duplicates, and ensuring column consistency. This stage lays the groundwork, ensuring that the data shines brightly and is primed for analysis.
#
# Then comes Module 2, where SQL takes center stage, employing a diverse range of complex queries. These queries serve as a gateway to unveil hidden insights within the dataset, unveiling trends and behaviors in smartphone sales that might otherwise remain obscured.
#
# The synergy between Python's data cleaning and SQL's analytical capabilities exemplifies a data-driven exploration. This project isn't just about crunching numbers; it's an expedition into the world of smartphone sales analysis, where every step reveals new insights into market trends and consumer behavior.
#
# By the end of this project, Mark doesn't just analyze data; he uncovers the intricacies of smartphone sales, providing actionable insights that could steer business strategies and marketing decisions in the industry.
#
# Join Mark on this captivating journey, where every Python function and SQL query illuminates the path to understanding smartphone sales trends. Together, we'll decode the complexities of this dynamic market, offering invaluable insights to shape the future of the smartphone industry through data-driven analysis.

# %% [markdown]
# ## Module 1
# ### Task 1: Importing Smartphone Sales Data
#
# In our project, "Smartphone Sales Analysis," this initial task focuses on importing data from the 'dataset_mobile.csv' file. By loading this dataset, we initiate the analysis of smartphone sales, enabling us to dive deeper into understanding market trends and consumer behavior. This fundamental step is crucial as it sets the groundwork for our comprehensive analysis, allowing us to explore patterns and extract valuable insights from the smartphone sales data.

# %%
#--- Import Pandas ---
import pandas as pd

#--- Read in dataset ('dataset_mobile.csv') ----
# ---WRITE YOUR CODE FOR TASK 1 ---
df = pd.read_csv('./dataset_mobile.csv')

#--- Inspect data ---
df
# Out:
#       m_brand m_model          m_color memory_ Storage_  Rating_     sp  \
# 0        OPPO     A53  Moonlight Black    4 GB    64 GB      4.5  11990
# 1        OPPO     A53       Mint Cream    4 GB    64 GB      4.5  11990
# 2        OPPO     A53  Moonlight Black    6 GB   128 GB      4.3  13990
# 3        OPPO     A53       Mint Cream    6 GB   128 GB      4.3  13990
# 4        OPPO     A53   Electric Black    4 GB    64 GB      4.5  11990
# ...       ...     ...              ...     ...      ...      ...    ...
# 3109  SAMSUNG  M52 5G    Blazing Black    6 GB   128 GB      4.3  25990
# 3110  SAMSUNG  M52 5G         Icy Blue    6 GB   128 GB      4.3  25489
# 3111  SAMSUNG  M52 5G         Icy Blue    8 GB   128 GB      4.3  27239
# 3112  SAMSUNG  M52 5G      Slate Black    8 GB   128 GB      4.2  22989
# 3113  SAMSUNG  M52 5G         Sky Blue    8 GB   128 GB      4.2  20350
#
#       Orig price camera
# 0          15990    Yes
# 1          15990    Yes
# 2          17990    Yes
# 3          17990    Yes
# 4          15990    Yes
# ...          ...    ...
# 3109       25990    Yes
# 3110       28449    Yes
# 3111       31489    Yes
# 3112       22989    Yes
# 3113       22595    Yes
#
# [3114 rows x 9 columns]

# %% [markdown]
# ### Task 2: Understanding Data Types
#
# In our "Smartphone Sales Analysis" project, this task involves examining the data types within the dataset imported from 'dataset_mobile.csv'. By using the 'dtypes' function, we aim to understand the nature of the data attributes present in the dataset. This step is essential as it provides insights into the format and structure of the information, aiding us in appropriate data manipulation and analysis for a more comprehensive understanding of smartphone sales trends.

# %%
# --- WRITE YOUR CODE FOR TASK 2 ---
datatype = df.dtypes

#--- Inspect data ---
datatype
# Out:
# m_brand        object
# m_model        object
# m_color        object
# memory_        object
# Storage_       object
# Rating_       float64
# sp              int64
# Orig price      int64
# camera         object
# dtype: object

# %% [markdown]
# ### Task 3: Identifying Duplicate Records
#
# In our "Smartphone Sales Analysis" project, this task involves identifying and quantifying duplicate records within the dataset. By using the 'duplicated' function and summing the duplicate occurrences, we aim to understand the extent of redundancy present in the dataset. Recognizing and handling duplicate entries is crucial as it ensures data accuracy and reliability for our analysis, preventing any distortions that may arise from repeated information in the smartphone sales dataset.

# %%
# --- WRITE YOUR CODE FOR TASK 3 ---
duplicates = df.duplicated().sum()

#--- Inspect data ---
duplicates
# Out:
# 108

# %% [markdown]
# ### Task 4: Removing Duplicate Records
#
# In our "Smartphone Sales Analysis" project, this task involves eliminating duplicate records from the dataset. By executing the code provided, we ensure that our dataset consists only of unique entries, enhancing the data's accuracy and reliability. This step is crucial as it helps prevent redundancy and ensures that our analysis is based on distinct and meaningful smartphone sales data, free from any potential distortions caused by repeated entries.

# %%
# --- WRITE YOUR CODE FOR TASK 4 ---
df.drop_duplicates(keep='first', inplace=True)

#--- Inspect data ---
df.head()
# Out:
#   m_brand m_model          m_color memory_ Storage_  Rating_     sp  \
# 0    OPPO     A53  Moonlight Black    4 GB    64 GB      4.5  11990
# 1    OPPO     A53       Mint Cream    4 GB    64 GB      4.5  11990
# 2    OPPO     A53  Moonlight Black    6 GB   128 GB      4.3  13990
# 3    OPPO     A53       Mint Cream    6 GB   128 GB      4.3  13990
# 4    OPPO     A53   Electric Black    4 GB    64 GB      4.5  11990
#
#    Orig price camera
# 0       15990    Yes
# 1       15990    Yes
# 2       17990    Yes
# 3       17990    Yes
# 4       15990    Yes

# %% [markdown]
# ### Task 5: Renaming Columns for Clarity
#
# In our "Smartphone Sales Analysis" project, this task involves renaming columns within the dataset to enhance readability and clarity. By using the provided 'new_columns' dictionary, we update column names to ensure better comprehension and standardization. This step is crucial as it streamlines the dataset, making it easier to interpret and analyze smartphone sales data, ensuring a more coherent and consistent representation of information for our analysis.

# %%
# --- WRITE YOUR CODE FOR TASK 5 ---
new_columns = {'m_brand':'Brand', 'm_model':'Model', 'memory_':'Memory',\
              'Storage_':'Storage', 'Rating_':'Rating', 'sp':\
              'Selling Price', 'Orig price':'Original Price', \
              'm_color':'color'}
df.rename(columns=new_columns, inplace=True)

#--- Inspect data ---
df
# Out:
#         Brand   Model            color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price camera
# 0              15990    Yes
# 1              15990    Yes
# 2              17990    Yes
# 3              17990    Yes
# 4              15990    Yes
# ...              ...    ...
# 3109           25990    Yes
# 3110           28449    Yes
# 3111           31489    Yes
# 3112           22989    Yes
# 3113           22595    Yes
#
# [3006 rows x 9 columns]

# %% [markdown]
# ### Task 6: Deriving Additional Columns
#
# In our "Smartphone Sales Analysis" project, this task involves creating new columns in the dataset to derive additional insights. By concatenating 'Brand' and 'Model' columns to create a new 'Mobile' column, calculating the 'Discount' based on 'Original Price' and 'Selling Price', and computing the 'discount_percentage', we aim to extract valuable information. These newly derived columns provide a deeper understanding of the dataset, facilitating more comprehensive analysis and interpretation of smartphone sales data and pricing trends.

# %%
# --- WRITE YOUR CODE FOR TASK 6 ---
df['Mobile'] = df.Brand.str.cat(df.Model, sep=' ')

df['Discount'] = df['Original Price'] - df['Selling Price']

df['discount_percentage'] = df['Discount']/df['Original Price'] * 100
#--- Inspect data ---
df
# Out:
#         Brand   Model            color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price camera          Mobile  Discount  discount_percentage
# 0              15990    Yes        OPPO A53      4000            25.015635
# 1              15990    Yes        OPPO A53      4000            25.015635
# 2              17990    Yes        OPPO A53      4000            22.234575
# 3              17990    Yes        OPPO A53      4000            22.234575
# 4              15990    Yes        OPPO A53      4000            25.015635
# ...              ...    ...             ...       ...                  ...
# 3109           25990    Yes  SAMSUNG M52 5G         0             0.000000
# 3110           28449    Yes  SAMSUNG M52 5G      2960            10.404584
# 3111           31489    Yes  SAMSUNG M52 5G      4250            13.496777
# 3112           22989    Yes  SAMSUNG M52 5G         0             0.000000
# 3113           22595    Yes  SAMSUNG M52 5G      2245             9.935827
#
# [3006 rows x 12 columns]

# %% [markdown]
# ### Task 7: Removing Unnecessary Columns
#
# In our "Smartphone Sales Analysis" project, this task involves eliminating specific columns ('Model' and 'camera') from the dataset. By executing the code provided, we streamline the dataset, removing redundant or unnecessary columns that might not contribute significantly to our analysis. This step ensures a more focused and relevant dataset for our smartphone sales analysis, allowing us to concentrate on essential factors impacting sales without irrelevant attributes.

# %%
# --- WRITE YOUR CODE FOR TASK 7 ---
columns = ['Model', 'camera']
df.drop(columns=columns, axis=columns, inplace=True)
df

#--- Inspect data ---
# Out:
#         Brand            color Memory Storage  Rating  Selling Price  \
# 0        OPPO  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price          Mobile  Discount  discount_percentage
# 0              15990        OPPO A53      4000            25.015635
# 1              15990        OPPO A53      4000            25.015635
# 2              17990        OPPO A53      4000            22.234575
# 3              17990        OPPO A53      4000            22.234575
# 4              15990        OPPO A53      4000            25.015635
# ...              ...             ...       ...                  ...
# 3109           25990  SAMSUNG M52 5G         0             0.000000
# 3110           28449  SAMSUNG M52 5G      2960            10.404584
# 3111           31489  SAMSUNG M52 5G      4250            13.496777
# 3112           22989  SAMSUNG M52 5G         0             0.000000
# 3113           22595  SAMSUNG M52 5G      2245             9.935827
#
# [3006 rows x 10 columns]

# %% [markdown]
# ### Task 8: Identifying Null Values
#
# In our "Smartphone Sales Analysis" project, this task involves identifying and quantifying null values within the dataset. The code snippet provided computes the count of null values present in each column. Understanding the extent of missing data is crucial as it enables us to handle and address any potential data gaps or inconsistencies. This step ensures data completeness and reliability for our analysis, helping us make informed decisions on managing missing values within the smartphone sales dataset.

# %%
# --- WRITE YOUR CODE FOR TASK 8 ---
null_values = df.isnull().sum()

#--- Inspect data ---
null_values
# Out:
# Brand                    0
# color                    0
# Memory                  40
# Storage                 39
# Rating                 130
# Selling Price            0
# Original Price           0
# Mobile                   0
# Discount                 0
# discount_percentage      0
# dtype: int64

# %% [markdown]
# ### Task 9: Handling Null Values and Saving Cleaned Dataset
#
# In our "Smartphone Sales Analysis" project, this task involves removing rows with null values from the dataset using 'dropna()'. The cleaned dataset is then saved to a new CSV file named 'cleaned_dataset.csv' without including the index column. This step ensures that our dataset is devoid of any missing values, providing a refined and complete dataset for further analysis and ensuring the integrity of our insights derived from the smartphone sales data.

# %%
# --- WRITE YOUR CODE FOR TASK 9 ---

#--- Export the df as "cleaned_dataset.csv" ---
df.dropna(inplace=True)

# df.to_csv('cleaned_dataset.csv', index=False)
#--- Inspect data ---
df
# Out:
#         Brand            color Memory Storage  Rating  Selling Price  \
# 0        OPPO  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price          Mobile  Discount  discount_percentage
# 0              15990        OPPO A53      4000            25.015635
# 1              15990        OPPO A53      4000            25.015635
# 2              17990        OPPO A53      4000            22.234575
# 3              17990        OPPO A53      4000            22.234575
# 4              15990        OPPO A53      4000            25.015635
# ...              ...             ...       ...                  ...
# 3109           25990  SAMSUNG M52 5G         0             0.000000
# 3110           28449  SAMSUNG M52 5G      2960            10.404584
# 3111           31489  SAMSUNG M52 5G      4250            13.496777
# 3112           22989  SAMSUNG M52 5G         0             0.000000
# 3113           22595  SAMSUNG M52 5G      2245             9.935827
#
# [2806 rows x 10 columns]

# %% [markdown]
# ## Module 2
# ### Task 1: Data Download, Import, and Database Connection

# %%
# -- Load the sql extention ----
# %load_ext sql

# --- Load your mysql db using credentials from the "DB" area ---
# %sql mysql+pymysql://<user>:<password>@localhost/<db_name>
# %sql mysql+pymysql://b31eec63:Cab%2322se@localhost/b31eec63

# %sql select * from cleaned_dataset;
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 2806 rows affected.
# [('OPPO', 'Moonlight Black', '4 GB', '64 GB', Decimal('4.5'), 11990, 15990, 'OPPO A53', 4000, '25.01563477173233'),
#  ('OPPO', 'Mint Cream', '4 GB', '64 GB', Decimal('4.5'), 11990, 15990, 'OPPO A53', 4000, '25.01563477173233'),
#  ('OPPO', 'Moonlight Black', '6 GB', '128 GB', Decimal('4.3'), 13990, 17990, 'OPPO A53', 4000, '22.234574763757642'),
#  ('OPPO', 'Mint Cream', '6 GB', '128 GB', Decimal('4.3'), 13990, 17990, 'OPPO A53', 4000, '22.234574763757642'),
#  ('OPPO', 'Electric Black', '4 GB', '64 GB', Decimal('4.5'), 11990, 15990, 'OPPO A53', 4000, '25.01563477173233'),
#  ('OPPO', 'Electric Black', '6 GB', '128 GB', Decimal('4.3'), 13990, 17990, 'OPPO A53', 4000, '22.234574763757642'),
#  ('OPPO', 'Deep Blue', '4 GB', '64 GB', Decimal('4.4'), 10490, 11990, 'OPPO A12', 1500, '12.51042535446205'),
#  ('OPPO', 'Black', '3 GB', '32 GB', Decimal('4.4'), 9490, 10990, 'OPPO A12', 1500, '13.64877161055505'),
#  ('OPPO', 'Blue', '3 GB', '32 GB', Decimal('4.4'), 9490, 10990, 'OPPO A12', 1500, '13.64877161055505'),
#  ('OPPO', 'Flowing Silver', '3 GB', '32 GB', Decimal('4.4'), 9490, 10990, 'OPPO A12', 1500, '13.64877161055505'),
#  ('OPPO', 'Deep Blue', '3 GB', '32 GB', Decimal('4.4'), 9490, 10990, 'OPPO A12', 1500, '13.64877161055505'),
#  ('OPPO', 'Flowing Silver', '4 GB', '64 GB', Decimal('4.4'), 10490, 11990, 'OPPO A12', 1500, '12.51042535446205'),
#  ('OPPO', 'Crystal Blue', '6 GB', '128 GB', Decimal('4.3'), 15990, 16990, 'OPPO A53s 5G', 1000, '5.885815185403178'),
#  ('OPPO', 'Ink Black', '6 GB', '128 GB', Decimal('4.3'), 15990, 16990, 'OPPO A53s 5G', 1000, '5.885815185403178'),
#  ('OPPO', 'Blue', '4 GB', '64 GB', Decimal('4.4'), 10490, 11990, 'OPPO A12', 1500, '12.51042535446205'),
#  ('OPPO', 'Crystal Blue', '8 GB', '128 GB', Decimal('4.3'), 17990, 18990, 'OPPO A53s 5G', 1000, '5.26592943654555'),
#  ('OPPO', 'Ink Black', '8 GB', '128 GB', Decimal('4.3'), 17990, 18990, 'OPPO A53s 5G', 1000, '5.26592943654555'),
#  ('OPPO', 'Moonlight Black', '3 GB', '32 GB', Decimal('4.3'), 10490, 12990, 'OPPO A33', 2500, '19.24557351809084'),
#  ('OPPO', 'Lake Green', '4 GB', '64 GB', Decimal('4.3'), 11960, 12990, 'OPPO A31', 1030, '7.929176289453426'),
#  ('OPPO', 'Mystery Black', '4 GB', '64 GB', Decimal('4.3'), 11779, 11919, 'OPPO A31', 140, '1.1745951841597448'),
#  ('OPPO', 'Fantastic Purple', '6 GB', '128 GB', Decimal('4.3'), 18979, 18979, 'OPPO A74 5G', 0, '0.0'),
#  ('OPPO', 'Flowing Silver', '2 GB', '32 GB', Decimal('4.2'), 8990, 10990, 'OPPO A11K', 2000, '18.198362147406733'),
#  ('OPPO', 'Matte Black', '8 GB', '128 GB', Decimal('4.3'), 19990, 25990, 'OPPO F17 Pro', 6000, '23.08580223162755'),
#  ('OPPO', 'Moonlight Gold', '4 GB', '128 GB', Decimal('4.3'), 15990, 15990, 'OPPO A54', 0, '0.0'),
#  ('OPPO', 'Moonlight Gold', '4 GB', '64 GB', Decimal('4.3'), 14990, 14990, 'OPPO A54', 0, '0.0'),
#  ('OPPO', 'Aurora', '8 GB', '128 GB', Decimal('4.3'), 29990, 35990, 'OPPO Reno6 5G', 6000, '16.67129758266185'),
#  ('OPPO', 'Stellar Black', '8 GB', '128 GB', Decimal('4.3'), 29990, 35990, 'OPPO Reno6 5G', 6000, '16.67129758266185'),
#  ('OPPO', 'Magic Blue', '8 GB', '128 GB', Decimal('4.3'), 19990, 25990, 'OPPO F17 Pro', 6000, '23.08580223162755'),
#  ('OPPO', 'Starry Blue', '4 GB', '64 GB', Decimal('4.3'), 14990, 14990, 'OPPO A54', 0, '0.0'),
#  ('OPPO', 'Starry Blue', '4 GB', '128 GB', Decimal('4.3'), 15990, 15990, 'OPPO A54', 0, '0.0'),
#  ('OPPO', 'Moonlight Gold', '6 GB', '128 GB', Decimal('4.3'), 16990, 17990, 'OPPO A54', 1000, '5.558643690939411'),
#  ('OPPO', 'Starry Blue', '6 GB', '128 GB', Decimal('4.3'), 16990, 17990, 'OPPO A54', 1000, '5.558643690939411'),
#  ('OPPO', 'Crystal Black', '4 GB', '64 GB', Decimal('4.3'), 14990, 14990, 'OPPO A54', 0, '0.0'),
#  ('OPPO', 'Metallic White', '8 GB', '128 GB', Decimal('4.3'), 19990, 25990, 'OPPO F17 Pro', 6000, '23.08580223162755'),
#  ('OPPO', 'Fantasy White', '4 GB', '64 GB', Decimal('4.3'), 12199, 12319, 'OPPO A31', 120, '0.9741050409935871'),
#  ('OPPO', 'Navy Blue', '8 GB', '128 GB', Decimal('4.3'), 21990, 21990, 'OPPO F17', 0, '0.0'),
#  ('OPPO', 'Fancy Blue', '6 GB', '128 GB', Decimal('4.3'), 15999, 15999, 'OPPO A53', 0, '0.0'),
#  ('OPPO', 'Deep Blue', '2 GB', '32 GB', Decimal('4.2'), 8990, 10990, 'OPPO A11K', 2000, '18.198362147406733'),
#  ('OPPO', 'Crystal Black', '4 GB', '128 GB', Decimal('4.3'), 15990, 15990, 'OPPO A54', 0, '0.0'),
#  ('OPPO', 'Astral Blue', '8 GB', '128 GB', Decimal('4.4'), 35990, 38990, 'OPPO Reno5 Pro 5G', 3000, '7.694280584765324'),
#  ('OPPO', 'Dynamic Black', '3 GB', '32 GB', Decimal('4.3'), 10990, 12990, 'OPPO A15', 2000, '15.396458814472672'),
#  ('OPPO', 'Dynamic Orange', '6 GB', '128 GB', Decimal('4.2'), 16990, 20990, 'OPPO F17', 4000, '19.05669366364936'),
#  ('OPPO', 'Mystery Blue', '3 GB', '32 GB', Decimal('4.3'), 10990, 12990, 'OPPO A15', 2000, '15.396458814472672'),
#  ('OPPO', 'Fairy White', '4 GB', '64 GB', Decimal('4.5'), 13499, 13499, 'OPPO A53', 0, '0.0'),
#  ('OPPO', 'Fairy White', '6 GB', '128 GB', Decimal('4.3'), 15999, 15999, 'OPPO A53', 0, '0.0'),
#  ('OPPO', 'Fluid Black', '6 GB', '128 GB', Decimal('4.3'), 18380, 18380, 'OPPO A74 5G BLACK', 0, '0.0'),
#  ('OPPO', 'Stellar Black', '12 GB', '256 GB', Decimal('4.4'), 39990, 46990, 'OPPO Reno6 Pro 5G', 7000, '14.896786550329857'),
#  ('OPPO', 'Crystal Black', '6 GB', '128 GB', Decimal('4.3'), 16990, 17990, 'OPPO A54', 1000, '5.558643690939411'),
#  ('OPPO', 'Sky White', '6 GB', '256 GB', Decimal('4.4'), 19990, 19990, 'OPPO Reno2 F', 0, '0.0'),
#  ('OPPO', 'Lake Green', '6 GB', '256 GB', Decimal('4.4'), 19990, 19990, 'OPPO Reno2 F', 0, '0.0'),
#  ('OPPO', 'Midnight Black', '8 GB', '256 GB', Decimal('4.4'), 26798, 28989, 'OPPO Reno3 Pro', 2191, '7.558039256269619'),
#  ('OPPO', 'Navy Blue', '6 GB', '128 GB', Decimal('4.2'), 16990, 20990, 'OPPO F17', 4000, '19.05669366364936'),
#  ('OPPO', 'Dynamic Black', '4 GB', '64 GB', Decimal('4.3'), 12990, 13990, 'OPPO A15s', 1000, '7.147962830593281'),
#  ('OPPO', 'Rainbow Silver', '4 GB', '64 GB', Decimal('4.3'), 12990, 13990, 'OPPO A15S', 1000, '7.147962830593281'),
#  ('OPPO', 'Auroral Blue', '8 GB', '256 GB', Decimal('4.4'), 27990, 35990, 'OPPO Reno3 Pro', 8000, '22.228396776882466'),
#  ('OPPO', 'Crystal Silver', '8 GB', '128 GB', Decimal('4.3'), 21990, 23990, 'OPPO F19 Pro', 2000, '8.336807002917883'),
#  ('OPPO', 'Fantastic Purple', '8 GB', '256 GB', Decimal('4.3'), 23490, 25990, 'OPPO F19 Pro', 2500, '9.619084263178145'),
#  ('OPPO', 'Space Silver', '8 GB', '128 GB', Decimal('4.3'), 25990, 29990, 'OPPO F19 Pro+ 5G', 4000, '13.337779259753251'),
#  ('OPPO', 'Fluid Black', '8 GB', '128 GB', Decimal('4.3'), 25990, 29990, 'OPPO F19 Pro+ 5G', 4000, '13.337779259753251'),
#  ('OPPO', 'Fancy White', '4 GB', '64 GB', Decimal('4.3'), 12889, 12989, 'OPPO A15S', 100, '0.7698822080221726'),
#  ('OPPO', 'Fluid Black', '8 GB', '128 GB', Decimal('4.3'), 21990, 23990, 'OPPO F19 Pro', 2000, '8.336807002917883'),
#  ('OPPO', 'Crystal Silver', '8 GB', '256 GB', Decimal('4.3'), 23490, 25990, 'OPPO F19 Pro', 2500, '9.619084263178145'),
#  ('OPPO', 'Fluid Black', '8 GB', '256 GB', Decimal('4.3'), 23490, 25990, 'OPPO F19 Pro', 2500, '9.619084263178145'),
#  ('OPPO', 'Fantastic Purple', '8 GB', '128 GB', Decimal('4.3'), 21990, 23990, 'OPPO F19 Pro', 2000, '8.336807002917883'),
#  ('OPPO', 'Fancy Blue', '4 GB', '64 GB', Decimal('4.5'), 13499, 13499, 'OPPO A53', 0, '0.0'),
#  ('OPPO', 'Midnight Blue', '6 GB', '128 GB', Decimal('4.2'), 19990, 20990, 'OPPO F19', 1000, '4.76417341591234'),
#  ('OPPO', 'Mystery Blue', '2 GB', '32 GB', Decimal('4.0'), 9989, 9989, 'OPPO A15', 0, '0.0'),
#  ('OPPO', 'Auroral Blue', '8 GB', '128 GB', Decimal('4.4'), 24989, 24989, 'OPPO Reno3 Pro', 0, '0.0'),
#  ('OPPO', 'Glaring Gold', '4 GB', '64 GB', Decimal('4.4'), 10990, 18990, 'OPPO A7', 8000, '42.1274354923644'),
#  ('OPPO', 'Rainbow Silver', '3 GB', '32 GB', Decimal('4.3'), 11249, 11249, 'OPPO A15', 0, '0.0'),
#  ('OPPO', 'Starry Black', '8 GB', '128 GB', Decimal('4.4'), 35990, 38990, 'OPPO Reno5 Pro 5G', 3000, '7.694280584765324'),
#  ('OPPO', 'Red', '6 GB', '64 GB', Decimal('4.4'), 24990, 24990, 'OPPO F5', 0, '0.0'),
#  ('OPPO', 'Blue', '2 GB', '32 GB', Decimal('4.3'), 8990, 12990, 'OPPO A5s', 4000, '30.792917628945343'),
#  ('OPPO', 'JET BLACK', '8 GB', '128 GB', Decimal('4.4'), 29999, 29999, 'OPPO Reno', 0, '0.0'),
#  ('OPPO', 'Luminous Black', '8 GB', '256 GB', Decimal('4.5'), 29489, 29489, 'OPPO Reno2 Z', 0, '0.0'),
#  ('OPPO', 'Aurora', '12 GB', '256 GB', Decimal('4.4'), 39990, 46990, 'OPPO Reno6 Pro 5G', 7000, '14.896786550329857'),
#  ('OPPO', 'Unicorn White', '4 GB', '128 GB', Decimal('4.4'), 15990, 20990, 'OPPO F15', 5000, '23.820867079561697'),
#  ('OPPO', 'Prism Black', '6 GB', '128 GB', Decimal('4.2'), 19990, 20990, 'OPPO F19', 1000, '4.76417341591234'),
#  ('OPPO', 'Piano Black', '6 GB', '64 GB', Decimal('4.3'), 13990, 20990, 'OPPO K1', 7000, '33.34921391138637'),
#  ('OPPO', 'Classic Silver', '6 GB', '128 GB', Decimal('4.2'), 20999, 20999, 'OPPO F17', 0, '0.0'),
#  ('OPPO', 'Lightening Black', '4 GB', '128 GB', Decimal('4.4'), 15990, 20990, 'OPPO F15', 5000, '23.820867079561697'),
#  ('OPPO', 'Sky White', '8 GB', '128 GB', Decimal('4.4'), 24719, 25489, 'OPPO Reno3 Pro', 770, '3.02091098120758'),
#  ('OPPO', 'Midnight Black', '8 GB', '128 GB', Decimal('4.4'), 24768, 24990, 'OPPO Reno3 Pro', 222, '0.8883553421368546'),
#  ('OPPO', 'Marine Green', '4 GB', '128 GB', Decimal('4.3'), 14990, 18990, 'OPPO A9 2020', 4000, '21.0637177461822'),
#  ('OPPO', 'Bordeaux Red', '8 GB', '256 GB', Decimal('4.6'), 60990, 60990, 'OPPO Find X', 0, '0.0'),
#  ('OPPO', 'Galactic Blue', '8 GB', '128 GB', Decimal('4.4'), 34990, 37990, 'OPPO Reno4 Pro Special Edition', 3000, '7.896814951302974'),
#  ('OPPO', 'Marble Green', '6 GB', '128 GB', Decimal('4.4'), 17990, 23990, 'OPPO F11', 6000, '25.010421008753646'),
#  ('OPPO', 'Diamond Blue', '4 GB', '64 GB', Decimal('4.4'), 15990, 15990, 'OPPO A5', 0, '0.0'),
#  ('OPPO', 'Silky White', '8 GB', '128 GB', Decimal('4.4'), 34990, 37990, 'OPPO Reno4 Pro', 3000, '7.896814951302974'),
#  ('OPPO', 'Starry Night', '8 GB', '128 GB', Decimal('4.4'), 34990, 37990, 'OPPO Reno4 Pro', 3000, '7.896814951302974'),
#  ('OPPO', 'Space Silver', '6 GB', '128 GB', Decimal('4.2'), 19990, 20990, 'OPPO F19', 1000, '4.76417341591234'),
#  ('OPPO', 'Black', '4 GB', '64 GB', Decimal('4.4'), 10990, 10990, 'OPPO A12', 0, '0.0'),
#  ('OPPO', 'Space Purple', '4 GB', '128 GB', Decimal('4.3'), 14990, 18990, 'OPPO A9 2020', 4000, '21.0637177461822'),
#  ('OPPO', 'Sky White', '8 GB', '128 GB', Decimal('4.4'), 21990, 28990, 'OPPO Reno2 F', 7000, '24.146257330113833'),
#  ('OPPO', 'Dazzling White', '3 GB', '64 GB', Decimal('4.4'), 12990, 14990, 'OPPO A5 2020', 2000, '13.342228152101402'),
#  ('OPPO', 'Rose Gold', '4 GB', '64 GB', Decimal('4.3'), 17000, 17000, 'OPPO F3 Deepika Padukone Limited Edition', 0, '0.0'),
#  ('OPPO', 'Gold', '4 GB', '64 GB', Decimal('4.0'), 27500, 27500, 'OPPO F1 Plus', 0, '0.0'),
#  ('OPPO', 'Piano Black', '4 GB', '64 GB', Decimal('4.4'), 15000, 15000, 'OPPO K1', 0, '0.0'),
#  ('OPPO', 'Blue', '4 GB', '64 GB', Decimal('4.3'), 15000, 15000, 'OPPO A83 2018 Edition', 0, '0.0'),
#  ('OPPO', 'Rose Gold', '4 GB', '64 GB', Decimal('4.3'), 18000, 18000, 'OPPO F3', 0, '0.0'),
#  ('OPPO', 'Blazing Blue', '4 GB', '128 GB', Decimal('4.4'), 15990, 20990, 'OPPO F15', 5000, '23.820867079561697'),
#  ('OPPO', 'Purple', '4 GB', '64 GB', Decimal('4.3'), 15000, 15000, 'OPPO A3s', 0, '0.0'),
#  ('OPPO', 'Champagne', '2 GB', '16 GB', Decimal('4.2'), 11000, 11000, 'OPPO A83', 0, '0.0'),
#  ('OPPO', 'Aurora Blue', '6 GB', '64 GB', Decimal('4.3'), 23990, 24667, 'OPPO K3', 677, '2.744557505979649'),
#  ('OPPO', 'Mist Black', '4 GB', '64 GB', Decimal('4.5'), 19000, 19000, 'OPPO F9', 0, '0.0'),
#  ('OPPO', 'Sky White', '8 GB', '256 GB', Decimal('4.5'), 29489, 32990, 'OPPO Reno2 Z', 3501, '10.612306759624127'),
#  ('OPPO', 'Black', '3 GB', '32 GB', Decimal('4.4'), 9490, 12990, 'OPPO A5s', 3500, '26.943802925327176'),
#  ('OPPO', 'Red', '4 GB', '64 GB', Decimal('4.3'), 13990, 13990, 'OPPO A83', 0, '0.0'),
#  ('OPPO', 'Black', '4 GB', '32 GB', Decimal('4.4'), 15500, 15500, 'OPPO F5', 0, '0.0'),
#  ('OPPO', 'Twilight Black', '6 GB', '128 GB', Decimal('4.3'), 17999, 17999, 'OPPO A52', 0, '0.0'),
#  ('OPPO', 'Stream White', '6 GB', '128 GB', Decimal('4.3'), 17999, 17999, 'OPPO A52', 0, '0.0'),
#  ('OPPO', 'Black', '3 GB', '16 GB', Decimal('4.4'), 9940, 9940, 'OPPO A71 New Edition', 0, '0.0'),
#  ('OPPO', 'Black', '2 GB', '32 GB', Decimal('4.3'), 12990, 12990, 'OPPO A5s', 0, '0.0'),
#  ('OPPO', 'Black', '1 GB', '16 GB', Decimal('3.8'), 10000, 10000, 'OPPO Neo 7 4G', 0, '0.0'),
#  ('OPPO', 'Gold', '4 GB', '64 GB', Decimal('4.4'), 15726, 15726, 'OPPO A5s', 0, '0.0'),
#  ('OPPO', 'Gold', '4 GB', '64 GB', Decimal('4.3'), 18000, 18000, 'OPPO F3', 0, '0.0'),
#  ('OPPO', 'Black', '3 GB', '16 GB', Decimal('4.2'), 12500, 12500, 'OPPO A71', 0, '0.0'),
#  ('OPPO', 'Gold', '3 GB', '16 GB', Decimal('4.2'), 12500, 12500, 'OPPO A71', 0, '0.0'),
#  ('OPPO', 'Lightening Black', '8 GB', '128 GB', Decimal('4.4'), 18990, 22990, 'OPPO F15', 4000, '17.398869073510223'),
#  ('OPPO', 'Blazing Blue', '8 GB', '128 GB', Decimal('4.4'), 18990, 22990, 'OPPO F15', 4000, '17.398869073510223'),
#  ('OPPO', 'Gold', '3 GB', '32 GB', Decimal('4.2'), 18000, 18000, 'OPPO A57', 0, '0.0'),
#  ('OPPO', 'Mystery Black', '6 GB', '128 GB', Decimal('4.3'), 13799, 13799, 'OPPO A31', 0, '0.0'),
#  ('OPPO', 'Fantasy White', '6 GB', '128 GB', Decimal('4.3'), 13899, 13899, 'OPPO A31', 0, '0.0'),
#  ('OPPO', 'Marine Green', '8 GB', '128 GB', Decimal('4.3'), 15990, 21990, 'OPPO A9 2020', 6000, '27.285129604365622'),
#  ('OPPO', 'Vanilla Mint', '4 GB', '128 GB', Decimal('4.3'), 14990, 18990, 'OPPO A9 2020', 4000, '21.0637177461822'),
#  ('OPPO', 'Lake Green', '8 GB', '128 GB', Decimal('4.4'), 25889, 25889, 'OPPO Reno2 F', 0, '0.0'),
#  ('OPPO', 'Red', '2 GB', '32 GB', Decimal('4.3'), 12990, 4990, 'OPPO A5s', -8000, '-160.32064128256513'),
#  ('OPPO', 'Red', '2 GB', '32 GB', Decimal('4.3'), 8490, 13400, 'OPPO A1K', 4910, '36.64179104477612'),
#  ('OPPO', 'Green', '4 GB', '64 GB', Decimal('4.4'), 15677, 15677, 'OPPO A5s', 0, '0.0'),
#  ('OPPO', 'Grey', '2 GB', '16 GB', Decimal('4.2'), 10000, 10000, 'OPPO A37f', 0, '0.0'),
#  ('OPPO', 'Sunrise Red', '6 GB', '64 GB', Decimal('4.5'), 19990, 25000, 'OPPO F9 Pro', 5010, '20.04'),
#  ('OPPO', 'Red', '3 GB', '32 GB', Decimal('4.3'), 12000, 12000, 'OPPO A3s', 0, '0.0'),
#  ('OPPO', 'Twilight Blue', '6 GB', '64 GB', Decimal('4.5'), 21150, 21150, 'OPPO F9 Pro', 0, '0.0'),
#  ('OPPO', 'Champagne', '3 GB', '32 GB', Decimal('4.4'), 14995, 14995, 'OPPO A83', 0, '0.0'),
#  ('OPPO', 'Red', '2 GB', '16 GB', Decimal('4.4'), 9500, 9500, 'OPPO A3s', 0, '0.0'),
#  ('OPPO', 'Starry Purple', '6 GB', '64 GB', Decimal('4.5'), 21150, 21150, 'OPPO F9 Pro', 0, '0.0'),
#  ('OPPO', 'Blue', '3 GB', '32 GB', Decimal('4.4'), 13750, 13750, 'OPPO A5s', 0, '0.0'),
#  ('OPPO', 'Red', '3 GB', '32 GB', Decimal('4.4'), 12990, 12990, 'OPPO A5s', 0, '0.0'),
#  ('OPPO', 'Purple', '3 GB', '32 GB', Decimal('4.3'), 12990, 12990, 'OPPO A3s', 0, '0.0'),
#  ('OPPO', 'Purple', '2 GB', '16 GB', Decimal('4.4'), 9500, 9500, 'OPPO A3s', 0, '0.0'),
#  ('OPPO', 'Diamond Blue', '4 GB', '32 GB', Decimal('4.4'), 15000, 15000, 'OPPO A5', 0, '0.0'),
#  ('OPPO', 'Diamond Red', '4 GB', '32 GB', Decimal('4.4'), 13500, 13500, 'OPPO A5', 0, '0.0'),
#  ('OPPO', 'Diamond Red', '4 GB', '64 GB', Decimal('4.4'), 15990, 15990, 'OPPO A5', 0, '0.0'),
#  ('OPPO', 'Stream White', '6 GB', '128 GB', Decimal('4.3'), 16990, 19990, 'OPPO A52', 3000, '15.007503751875939'),
#  ('OPPO', 'Mint Cream', '3 GB', '32 GB', Decimal('4.3'), 10490, 12990, 'OPPO A33', 2500, '19.24557351809084'),
#  ('OPPO', 'Dynamic Orange', '8 GB', '128 GB', Decimal('4.3'), 22990, 22990, 'OPPO F17', 0, '0.0'),
#  ('OPPO', 'Classic Silver', '8 GB', '128 GB', Decimal('4.3'), 22990, 22990, 'OPPO F17', 0, '0.0'),
#  ('OPPO', 'Dynamic Black', '4 GB', '128 GB', Decimal('4.3'), 13489, 13489, 'OPPO A15s', 0, '0.0'),
#  ('OPPO', 'Dynamic Black', '2 GB', '32 GB', Decimal('4.0'), 8990, 10990, 'OPPO A15', 2000, '18.198362147406733'),
#  ('OPPO', 'Twilight Black', '4 GB', '128 GB', Decimal('4.4'), 14990, 17990, 'OPPO A52', 3000, '16.67593107281823'),
#  ('OPPO', 'Sky White', '8 GB', '256 GB', Decimal('4.4'), 27990, 35990, 'OPPO Reno3 Pro', 8000, '22.228396776882466'),
#  ('OPPO', 'Glaring Gold', '3 GB', '64 GB', Decimal('4.3'), 10990, 16990, 'OPPO A7', 6000, '35.31489111241907'),
#  ('OPPO', 'Black', '2 GB', '32 GB', Decimal('4.3'), 7990, 10990, 'OPPO A1K', 3000, '27.2975432211101'),
#  ('OPPO', 'Twilight Black', '8 GB', '128 GB', Decimal('4.3'), 20990, 20990, 'OPPO A52', 0, '0.0'),
#  ('OPPO', 'Stream White', '8 GB', '128 GB', Decimal('4.3'), 20990, 20990, 'OPPO A52', 0, '0.0'),
#  ('OPPO', 'Stream White', '4 GB', '128 GB', Decimal('4.4'), 14990, 17990, 'OPPO A52', 3000, '16.67593107281823'),
#  ('OPPO', 'Blue', '4 GB', '64 GB', Decimal('4.4'), 10990, 15990, 'OPPO A5s', 5000, '31.269543464665418'),
#  ('OPPO', 'Black', '6 GB', '64 GB', Decimal('4.4'), 14990, 14990, 'OPPO F5', 0, '0.0'),
#  ('OPPO', 'Glaze Blue', '4 GB', '64 GB', Decimal('4.4'), 10990, 18990, 'OPPO A7', 8000, '42.1274354923644'),
#  ('OPPO', 'Red', '2 GB', '16 GB', Decimal('4.2'), 9990, 9990, 'OPPO A83', 0, '0.0'),
#  ('OPPO', 'Red', '4 GB', '64 GB', Decimal('4.3'), 13990, 13990, 'OPPO A3s', 0, '0.0'),
#  ('OPPO', 'Glaze Blue', '3 GB', '64 GB', Decimal('4.3'), 10990, 16990, 'OPPO A7', 6000, '35.31489111241907'),
#  ('OPPO', 'Mirror Black', '3 GB', '64 GB', Decimal('4.4'), 14990, 14990, 'OPPO A5 2020', 0, '0.0'),
#  ('OPPO', 'Champagne', '4 GB', '64 GB', Decimal('4.3'), 16990, 16990, 'OPPO A83', 0, '0.0'),
#  ('OPPO', 'Gold', '4 GB', '32 GB', Decimal('4.4'), 19990, 19990, 'OPPO F5', 0, '0.0'),
#  ('OPPO', 'Jade Black', '6 GB', '64 GB', Decimal('4.3'), 24990, 24990, 'OPPO K3', 0, '0.0'),
#  ('OPPO', 'Gold', '3 GB', '16 GB', Decimal('4.4'), 10990, 10990, 'OPPO A71k', 0, '0.0'),
#  ('OPPO', 'White', '1 GB', '16 GB', Decimal('3.8'), 8490, 8490, 'OPPO Neo 7 4G', 0, '0.0'),
#  ('OPPO', 'Astral Blue', '4 GB', '64 GB', Decimal('4.4'), 14990, 18990, 'OPPO K1', 4000, '21.0637177461822'),
#  ('OPPO', 'Astral Blue', '6 GB', '64 GB', Decimal('4.3'), 13990, 20990, 'OPPO K1', 7000, '33.34921391138637'),
#  ('OPPO', 'Jade Black', '8 GB', '128 GB', Decimal('4.2'), 30994, 30994, 'OPPO K3', 0, '0.0'),
#  ('OPPO', 'Black', '4 GB', '64 GB', Decimal('4.4'), 10990, 15990, 'OPPO A5s', 5000, '31.269543464665418'),
#  ('OPPO', 'Stellar Purple', '4 GB', '64 GB', Decimal('4.5'), 17890, 21990, 'OPPO F9', 4100, '18.644838562983175'),
#  ('OPPO', 'Black', '4 GB', '64 GB', Decimal('4.3'), 20990, 20990, 'OPPO F3', 0, '0.0'),
#  ('OPPO', 'Black', '3 GB', '32 GB', Decimal('4.2'), 14990, 14990, 'OPPO A57', 0, '0.0'),
#  ('OPPO', 'Marble Green', '4 GB', '128 GB', Decimal('4.4'), 12990, 16990, 'OPPO A9', 4000, '23.543260741612713'),
#  ('OPPO', 'Fluorite Purple', '4 GB', '128 GB', Decimal('4.4'), 12990, 16990, 'OPPO A9', 4000, '23.543260741612713'),
#  ('OPPO', 'Black', '6 GB', '64 GB', Decimal('4.3'), 22990, 22990, 'OPPO F3 Plus', 0, '0.0'),
#  ('OPPO', 'Gold', '6 GB', '64 GB', Decimal('4.3'), 22990, 22990, 'OPPO F3 Plus', 0, '0.0'),
#  ('OPPO', 'Black', '4 GB', '64 GB', Decimal('4.3'), 30990, 30990, 'OPPO F3 Plus', 0, '0.0'),
#  ('OPPO', 'Black', '4 GB', '64 GB', Decimal('4.4'), 22990, 22990, 'OPPO Rohit Sharma Limited Edition', 0, '0.0'),
#  ('OPPO', 'Gold', '8 GB', '128 GB', Decimal('4.3'), 21999, 21999, 'OPPO F17 PRO', 0, '0.0'),
#  ('OPPO', 'Black', '4 GB', '64 GB', Decimal('4.4'), 22990, 22990, 'OPPO Hardik Pandya Limited Editon', 0, '0.0'),
#  ('OPPO', 'Starry Night', '8 GB', '128 GB', Decimal('4.4'), 34990, 37990, 'OPPO Reno4 Pro Special Edition', 3000, '7.896814951302974'),
#  ('OPPO', 'Black', '4 GB', '64 GB', Decimal('4.4'), 22990, 22990, 'OPPO Ravichandran Ashwin Limited Edition', 0, '0.0'),
#  ('OPPO', 'Gold', '4 GB', '64 GB', Decimal('4.3'), 12990, 12990, 'OPPO F3 Plus', 0, '0.0'),
#  ('OPPO', 'Waterfall Grey', '6 GB', '128 GB', Decimal('4.5'), 14990, 29990, 'OPPO F11 Pro', 15000, '50.01667222407469'),
#  ('OPPO', 'Aurora Green', '6 GB', '128 GB', Decimal('4.5'), 17990, 29990, 'OPPO F11 Pro', 12000, '40.01333777925976'),
#  ('OPPO', 'White', '1 GB', '16 GB', Decimal('3.0'), 21452, 21452, 'OPPO R1 R829', 0, '0.0'),
#  ('OPPO', 'Fluorite Purple', '6 GB', '128 GB', Decimal('4.4'), 17990, 23990, 'OPPO F11', 6000, '25.010421008753646'),
#  ('OPPO', 'Fluorite Purple', '4 GB', '128 GB', Decimal('4.4'), 13990, 21990, 'OPPO F11', 8000, '36.38017280582083'),
#  ('OPPO', 'Vanilla Mint', '8 GB', '128 GB', Decimal('4.3'), 15990, 21990, 'OPPO A9 2020', 6000, '27.285129604365622'),
#  ('OPPO', 'Black', '1 GB', '16 GB', Decimal('3.0'), 24990, 24990, 'OPPO R1 R829', 0, '0.0'),
#  ('OPPO', 'Thunder Black', '6 GB', '64 GB', Decimal('4.5'), 16990, 28990, 'OPPO F11 Pro', 12000, '41.393583994480856'),
#  ('OPPO', 'Aurora Green', '6 GB', '64 GB', Decimal('4.5'), 16890, 28990, 'OPPO F11 Pro', 12100, '41.7385305277682'),
#  ('OPPO', 'Aurora Blue', '8 GB', '128 GB', Decimal('4.2'), 29999, 29999, 'OPPO K3', 0, '0.0'),
#  ('OPPO', 'Space Purple', '8 GB', '128 GB', Decimal('4.3'), 15990, 21990, 'OPPO A9 2020', 6000, '27.285129604365622'),
#  ('OPPO', 'Fancy white', '4 GB', '128 GB', Decimal('4.3'), 13489, 13489, 'OPPO A15S', 0, '0.0'),
#  ('OPPO', 'Rainbow Silver', '4 GB', '128 GB', Decimal('4.3'), 13489, 13489, 'OPPO A15s', 0, '0.0'),
#  ('OPPO', 'Blue', '3 GB', '16 GB', Decimal('4.4'), 10990, 10990, 'OPPO A71k', 0, '0.0'),
#  ('OPPO', 'Black', '3 GB', '32 GB', Decimal('4.3'), 17990, 17990, 'OPPO F5 Youth', 0, '0.0'),
#  ('OPPO', 'Gold', '3 GB', '32 GB', Decimal('4.3'), 17990, 17990, 'OPPO F5 Youth', 0, '0.0'),
#  ('OPPO', 'Jewelry White', '6 GB', '128 GB', Decimal('4.4'), 17990, 23990, 'OPPO F11', 6000, '25.010421008753646'),
#  ('OPPO', 'Black', '4 GB', '64 GB', Decimal('4.4'), 22990, 22990, 'OPPO F7', 0, '0.0'),
#  ('OPPO', 'Red', '4 GB', '64 GB', Decimal('4.4'), 22990, 22990, 'OPPO F7', 0, '0.0'),
#  ('OPPO', 'Silver', '4 GB', '64 GB', Decimal('4.4'), 22990, 22990, 'OPPO F7', 0, '0.0'),
#  ('OPPO', 'Glacier Blue', '8 GB', '256 GB', Decimal('4.6'), 60990, 60990, 'OPPO Find X', 0, '0.0'),
#  ('OPPO', 'Black', '1 GB', '16 GB', Decimal('3.8'), 4999, 7856, 'OPPO Neo 5', 2857, '36.367107942973526'),
#  ('OPPO', 'Red', '6 GB', '128 GB', Decimal('4.5'), 27990, 27990, 'OPPO F7', 0, '0.0'),
#  ('OPPO', 'Gold', '3 GB', '16 GB', Decimal('4.1'), 15739, 15739, 'OPPO F1', 0, '0.0'),
#  ('OPPO', 'Luminous Black', '8 GB', '256 GB', Decimal('4.4'), 38990, 39990, 'OPPO Reno2', 1000, '2.5006251562890722'),
#  ('OPPO', 'Black', '6 GB', '128 GB', Decimal('4.5'), 27990, 27990, 'OPPO F7', 0, '0.0'),
#  ('OPPO', 'White', '1 GB', '16 GB', Decimal('3.8'), 4999, 7490, 'OPPO Neo 5', 2491, '33.257676902536716'),
#  ('OPPO', 'Neon Purple', '8 GB', '128 GB', Decimal('3.7'), 38999, 38999, 'OPPO R17', 0, '0.0'),
#  ('OPPO', 'Rainbow Silver', '2 GB', '32 GB', Decimal('4.0'), 9490, 9500, 'OPPO A15', 10, '0.10526315789473684'),
#  ('OPPO', 'Unicorn White', '8 GB', '128 GB', Decimal('4.4'), 18990, 22990, 'OPPO F15', 4000, '17.398869073510223'),
#  ('OPPO', 'Jet Black', '6 GB', '128 GB', Decimal('4.5'), 38990, 41990, 'OPPO Reno 10x Zoom', 3000, '7.14455822814956'),
#  ('OPPO', 'Marble Green', '4 GB', '128 GB', Decimal('4.4'), 13990, 21990, 'OPPO F11', 8000, '36.38017280582083'),
#  ('OPPO', 'Majestic Gold', '12 GB', '256 GB', Decimal('4.4'), 41990, 45990, 'OPPO Reno6 Pro 5G', 4000, '8.697542944118286'),
#  ('OPPO', 'Black', '2 GB', '16 GB', Decimal('4.2'), 9990, 9990, 'OPPO A37f', 0, '0.0'),
#  ('OPPO', 'Grey', '3 GB', '32 GB', Decimal('4.2'), 12990, 12990, 'OPPO F1S', 0, '0.0'),
#  ('OPPO', 'Rose Gold', '4 GB', '64 GB', Decimal('4.0'), 24900, 24900, 'OPPO F1 Plus', 0, '0.0'),
#  ('OPPO', 'Black', '3 GB', '32 GB', Decimal('4.4'), 13490, 13490, 'OPPO A83', 0, '0.0'),
#  ('OPPO', 'Thunder Black', '6 GB', '128 GB', Decimal('4.5'), 17990, 29990, 'OPPO F11 Pro', 12000, '40.01333777925976'),
#  ('OPPO', 'Grey', '4 GB', '64 GB', Decimal('4.3'), 18990, 18990, 'OPPO F1S', 0, '0.0'),
#  ('OPPO', 'Rose Gold', '4 GB', '64 GB', Decimal('4.3'), 18990, 18990, 'OPPO F1S', 0, '0.0'),
#  ('OPPO', 'Gold', '4 GB', '64 GB', Decimal('4.3'), 18990, 18990, 'OPPO F1S', 0, '0.0'),
#  ('OPPO', 'Ocean Green', '6 GB', '128 GB', Decimal('4.5'), 38990, 41990, 'OPPO Reno 10x Zoom', 3000, '7.14455822814956'),
#  ('OPPO', 'Jet Black', '8 GB', '256 GB', Decimal('4.4'), 41990, 55990, 'OPPO Reno 10x Zoom', 14000, '25.00446508305054'),
#  ('OPPO', 'Ocean Green', '8 GB', '256 GB', Decimal('4.4'), 41990, 55990, 'OPPO Reno 10x Zoom', 14000, '25.00446508305054'),
#  ('OPPO', 'Gold', '2 GB', '16 GB', Decimal('4.2'), 9990, 9990, 'OPPO A37f', 0, '0.0'),
#  ('OPPO', 'Ocean Blue', '8 GB', '256 GB', Decimal('4.4'), 38990, 39990, 'OPPO Reno2', 1000, '2.5006251562890722'),
#  ('OPPO', 'White', '2 GB', '16 GB', Decimal('3.1'), 9990, 9990, 'OPPO N5111', 0, '0.0'),
#  ('OPPO', 'Starry purple', '6 GB', '128 GB', Decimal('4.5'), 21990, 27990, 'OPPO F9 Pro', 6000, '21.436227224008576'),
#  ('HTC', 'Amazing Silver', '6 GB', '128 GB', Decimal('4.7'), 56990, 56990, 'HTC U11+ ', 0, '0.0'),
#  ('HTC', 'Blue', '3 GB', '32 GB', Decimal('3.9'), 12999, 12999, 'HTC Wildfire X ', 0, '0.0'),
#  ('HTC', 'Blue', '4 GB', '128 GB', Decimal('3.9'), 16999, 16999, 'HTC Wildfire X ', 0, '0.0'),
#  ('HTC', 'Blue', '4 GB', '128 GB', Decimal('3.9'), 17999, 17999, 'HTC Wildfire X ', 0, '0.0'),
#  ('HTC', 'Blue MB', '3 GB', '32 GB', Decimal('3.9'), 13999, 13999, 'HTC Wildfire X ', 0, '0.0'),
#  ('IQOO', 'Quantum Silver', '8 GB', '128 GB', Decimal('4.4'), 34990, 37990, 'IQOO 3', 3000, '7.896814951302974'),
#  ('IQOO', 'Tornado Black', '8 GB', '128 GB', Decimal('4.4'), 34990, 37990, 'IQOO 3', 3000, '7.896814951302974'),
#  ('IQOO', 'Quantum Silver', '8 GB', '256 GB', Decimal('4.4'), 37990, 40990, 'IQOO 3', 3000, '7.318858258111735'),
#  ('IQOO', 'Tornado Black', '8 GB', '256 GB', Decimal('4.4'), 37990, 40990, 'IQOO 3', 3000, '7.318858258111735'),
#  ('IQOO', ' Tornado Black', '12 GB', '256 GB', Decimal('4.4'), 39990, 46990, 'IQOO 3', 7000, '14.896786550329857'),
#  ('Google Pixel', 'Just Black', '6 GB', '128 GB', Decimal('4.5'), 31999, 31999, 'Google Pixel 4a ', 0, '0.0'),
#  ('Google Pixel', 'Clearly White', '4 GB', '64 GB', Decimal('4.5'), 44999, 44999, 'Google Pixel 3a XL ', 0, '0.0'),
#  ('Google Pixel', 'Just Black', '4 GB', '64 GB', Decimal('4.5'), 69999, 69999, 'Google Pixel 3', 0, '0.0'),
#  ('Google Pixel', 'Just Black', '4 GB', '64 GB', Decimal('4.5'), 44999, 44999, 'Google Pixel 3a XL ', 0, '0.0'),
#  ('Google Pixel', 'Clearly White', '4 GB', '64 GB', Decimal('4.5'), 71000, 71000, 'Google Pixel 3', 0, '0.0'),
#  ('Google Pixel', 'Not Pink', '4 GB', '64 GB', Decimal('4.5'), 71000, 71000, 'Google Pixel 3', 0, '0.0'),
#  ('Google Pixel', 'Not Pink', '4 GB', '128 GB', Decimal('4.5'), 80000, 80000, 'Google Pixel 3', 0, '0.0'),
#  ('Google Pixel', 'Not Pink', '4 GB', '64 GB', Decimal('4.6'), 83000, 83000, 'Google Pixel 3 XL ', 0, '0.0'),
#  ('Google Pixel', 'Just Black', '4 GB', '64 GB', Decimal('4.6'), 83000, 83000, 'Google Pixel 3 XL ', 0, '0.0'),
#  ('Google Pixel', 'Clearly White', '4 GB', '128 GB', Decimal('4.6'), 92000, 92000, 'Google Pixel 3 XL ', 0, '0.0'),
#  ('Google Pixel', 'Just Black', '4 GB', '128 GB', Decimal('4.5'), 80000, 80000, 'Google Pixel 3', 0, '0.0'),
#  ('Google Pixel', 'Clearly White', '4 GB', '128 GB', Decimal('4.5'), 80000, 80000, 'Google Pixel 3', 0, '0.0'),
#  ('Google Pixel', 'Just Black', '4 GB', '128 GB', Decimal('4.6'), 92000, 92000, 'Google Pixel 3 XL ', 0, '0.0'),
#  ('Google Pixel', 'Clearly White', '4 GB', '64 GB', Decimal('4.6'), 83000, 83000, 'Google Pixel 3 XL ', 0, '0.0'),
#  ('Google Pixel', 'Clearly White', '4 GB', '64 GB', Decimal('4.5'), 39999, 39999, 'Google Pixel 3a ', 0, '0.0'),
#  ('Google Pixel', 'Very Silver', '4 GB', '128 GB', Decimal('4.5'), 76000, 76000, 'Google Pixel XL ', 0, '0.0'),
#  ('Google Pixel', 'Just Black', '4 GB', '128 GB', Decimal('4.6'), 82000, 82000, 'Google Pixel 2 XL ', 0, '0.0'),
#  ('Google Pixel', 'Just Black', '4 GB', '64 GB', Decimal('4.6'), 61000, 61000, 'Google Pixel 2', 0, '0.0'),
#  ('Google Pixel', 'Not Pink', '4 GB', '128 GB', Decimal('4.6'), 92000, 92000, 'Google Pixel 3 XL ', 0, '0.0'),
#  ('Google Pixel', 'Clearly White', '4 GB', '128 GB', Decimal('4.6'), 70000, 70000, 'Google Pixel 2', 0, '0.0'),
#  ('Google Pixel', 'Black', '4 GB', '128 GB', Decimal('4.4'), 66000, 66000, 'Google Pixel Quite Black', 0, '0.0'),
#  ('Google Pixel', 'Silver', '4 GB', '32 GB', Decimal('4.4'), 57000, 57000, 'Google Pixel Very Silver', 0, '0.0'),
#  ('Google Pixel', 'Just Black', '4 GB', '128 GB', Decimal('4.6'), 70000, 70000, 'Google Pixel 2', 0, '0.0'),
#  ('Google Pixel', 'Just Black', '4 GB', '64 GB', Decimal('4.5'), 39999, 39999, 'Google Pixel 3a ', 0, '0.0'),
#  ('LG', 'Black', '3 GB', '32 GB', Decimal('4.0'), 7690, 7799, 'LG W11 ', 109, '1.3976150788562636'),
#  ('LG', 'Aurora Silver', '6 GB', '128 GB', Decimal('4.4'), 44990, 55000, 'LG Velvet Dual Screen ', 10010, '18.2'),
#  ('LG', 'Blue', '3 GB', '64 GB', Decimal('4.0'), 9990, 9990, 'LG Q60 ', 0, '0.0'),
#  ('LG', 'White', '1 GB', '8 GB', Decimal('4.2'), 15532, 15532, 'LG L90 Dual ', 0, '0.0'),
#  ('LG', 'Midnight Blue', '4 GB', '64 GB', Decimal('4.0'), 9999, 9999, 'LG W31 ', 0, '0.0'),
#  ('LG', 'Midnight Blue', '4 GB', '128 GB', Decimal('4.1'), 10999, 10999, 'LG W31 Plus ', 0, '0.0'),
#  ('LG', 'Grey', '3 GB', '64 GB', Decimal('3.9'), 10990, 14000, 'LG K42 ', 3010, '21.5'),
#  ('LG', 'Black', '6 GB', '128 GB', Decimal('4.4'), 44990, 55000, 'LG Velvet Dual Screen ', 10010, '18.2'),
#  ('LG', 'midnight blue', '4 GB', '64 GB', Decimal('4.0'), 9999, 9999, 'LG W31 ', 0, '0.0'),
#  ('LG', 'Midnight Purple', '4 GB', '64 GB', Decimal('3.8'), 14999, 14999, 'LG W30 Pro ', 0, '0.0'),
#  ('LG', 'Midnight Blue', '4 GB', '64 GB', Decimal('3.8'), 13775, 14500, 'LG W30 Pro ', 725, '5.0'),
#  ('LG', 'Moroccan Blue', '2 GB', '16 GB', Decimal('4.1'), 5899, 7833, 'LG Candy K9 ', 1934, '24.69041235797268'),
#  ('LG', 'Black', '2 GB', '16 GB', Decimal('4.0'), 7999, 7999, 'LG K9 4G LTE ', 0, '0.0'),
#  ('LG', 'Smokey Gray', '3 GB', '32 GB', Decimal('3.9'), 6999, 9999, 'LG W10 ', 3000, '30.003000300030003'),
#  ('LG', 'Midnight Purple', '4 GB', '64 GB', Decimal('3.8'), 13998, 13998, 'LG W30 Pro ', 0, '0.0'),
#  ('LG', 'Black Blue', '2 GB', '16 GB', Decimal('4.0'), 7799, 7799, 'LG K-10 ', 0, '0.0'),
#  ('LG', 'MAGIC BLUE', '4 GB', '64 GB', Decimal('4.0'), 10499, 10499, 'LG W41 ', 0, '0.0'),
#  ('LG', 'Black', '4 GB', '64 GB', Decimal('4.0'), 24000, 24000, 'LG Q Stylus+ ', 0, '0.0'),
#  ('LG', 'Black', '3 GB', '32 GB', Decimal('3.7'), 7299, 7299, 'LG W10 Alpha ', 0, '0.0'),
#  ('LG', 'Thunder Blue', '3 GB', '32 GB', Decimal('3.9'), 8399, 8399, 'LG W30 ', 0, '0.0'),
#  ('LG', 'Thunder blue', '4 GB', '64 GB', Decimal('3.8'), 12950, 12950, 'LG W30 Plus ', 0, '0.0'),
#  ('LG', 'Platinum', '6 GB', '128 GB', Decimal('4.4'), 55000, 55000, 'LG G7+ ThinQ ', 0, '0.0'),
#  ('LG', 'Titan', '2 GB', '16 GB', Decimal('4.1'), 12999, 12999, 'LG Stylus 2 ', 0, '0.0'),
#  ('LG', 'Green', '3 GB', '64 GB', Decimal('3.9'), 10990, 14000, 'LG K42 ', 3010, '21.5'),
#  ('LG', 'Silver Titan', '1 GB', '8 GB', Decimal('3.4'), 5000, 11500, 'LG Max X160 ', 6500, '56.52173913043478'),
#  ('LG', 'Aurora Green', '4 GB', '64 GB', Decimal('3.8'), 12790, 12790, 'LG W30 Plus ', 0, '0.0'),
#  ('LG', 'Silver', '4 GB', '64 GB', Decimal('4.2'), 29199, 29199, 'LG V20 ', 0, '0.0'),
#  ('LG', 'Black', '6 GB', '128 GB', Decimal('4.4'), 27990, 70000, 'LG G8X ', 42010, '60.014285714285705'),
#  ('LG', 'Platinum Grey', '6 GB', '128 GB', Decimal('4.4'), 60000, 60000, 'LG V40 ThinQ ', 0, '0.0'),
#  ('LG', 'Brown', '2 GB', '16 GB', Decimal('4.0'), 9990, 9990, 'LG K7i ', 0, '0.0'),
#  ('LG', 'White', '2 GB', '16 GB', Decimal('4.5'), 26299, 26299, 'LG Nexus4 E960', 0, '0.0'),
#  ('LG', 'Black', '4 GB', '64 GB', Decimal('4.4'), 50000, 50000, 'LG G7 ThinQ ', 0, '0.0'),
#  ('LG', 'Platinum', '4 GB', '64 GB', Decimal('4.4'), 50000, 50000, 'LG G7 ThinQ ', 0, '0.0'),
#  ('Google Pixel', 'Ice', '2 GB', '16 GB', Decimal('4.3'), 25990, 25990, 'Google Pixel Nexus 5X ', 0, '0.0'),
#  ('LG', 'Silver', '4 GB', '32 GB', Decimal('4.0'), 52990, 52990, 'LG G5 ', 0, '0.0'),
#  ('LG', 'Platinum', '4 GB', '64 GB', Decimal('3.9'), 19990, 19990, 'LG Q6+ ', 0, '0.0'),
#  ('LG', 'Black Titan', '1 GB', '8 GB', Decimal('3.7'), 12500, 12500, 'LG Spirit 4G LTE ', 0, '0.0'),
#  ('LG', 'AURORA SILVER', '6 GB', '128 GB', Decimal('4.2'), 29999, 29999, 'LG Velvet ', 0, '0.0'),
#  ('LG', 'Magic Blue', '4 GB', '128 GB', Decimal('3.8'), 9499, 18000, 'LG W41 Plus ', 8501, '47.22777777777778'),
#  ('LG', 'Magic Blue', '4 GB', '64 GB', Decimal('4.0'), 8499, 16000, 'LG W41 ', 7501, '46.88125'),
#  ('LG', 'Aurora Gray', '8 GB', '128 GB', Decimal('4.2'), 29999, 80000, 'LG Wing ', 50001, '62.50125'),
#  ('LG', 'Laser Blue', '6 GB', '128 GB', Decimal('3.7'), 10499, 20000, 'LG W41 Pro ', 9501, '47.504999999999995'),
#  ('LG', 'Black', '6 GB', '128 GB', Decimal('4.4'), 55000, 55000, 'LG G7+ ThinQ ', 0, '0.0'),
#  ('LG', 'Black', '1 GB', '4 GB', Decimal('4.0'), 12791, 12791, 'LG Optimus L70 ', 0, '0.0'),
#  ('LG', 'White', '512 MB', '4 GB', Decimal('3.7'), 8800, 8800, 'LG L60 Dual ', 0, '0.0'),
#  ('LG', 'Black & Blue', '2 GB', '16 GB', Decimal('3.8'), 5699, 5699, 'LG K8 ', 0, '0.0'),
#  ('LG', 'Titan', '3 GB', '16 GB', Decimal('4.5'), 42021, 42021, 'LG G Pro 2 ', 0, '0.0'),
#  ('LG', 'Black', '512 MB', '4 GB', Decimal('4.5'), 10199, 10199, 'LG Optimus L5 II ', 0, '0.0'),
#  ('LG', 'Aurora Green', '3 GB', '32 GB', Decimal('3.9'), 9999, 9999, 'LG W30 ', 0, '0.0'),
#  ('LG', 'Silver', '4 GB', '128 GB', Decimal('4.3'), 29999, 29999, 'LG V30+ ', 0, '0.0'),
#  ('LG', 'Black', '4 GB', '128 GB', Decimal('4.3'), 29999, 29999, 'LG V30+ ', 0, '0.0'),
#  ('LG', 'Black Gold', '2 GB', '16 GB', Decimal('4.5'), 31971, 31971, 'LG G2 D802 ', 0, '0.0'),
#  ('LG', 'Black', '3 GB', '32 GB', Decimal('3.8'), 20000, 20000, 'LG Q Stylus ', 0, '0.0'),
#  ('LG', 'Platinum', '3 GB', '32 GB', Decimal('4.0'), 16990, 16990, 'LG Q6 ', 0, '0.0'),
#  ('LG', 'Black', '4 GB', '64 GB', Decimal('4.2'), 22990, 55000, 'LG G6 ', 32010, '58.199999999999996'),
#  ('LG', 'Titan', '2 GB', '16 GB', Decimal('4.1'), 7499, 7499, 'LG K10 2017 ', 0, '0.0'),
#  ('LG', 'Gold & Black', '2 GB', '16 GB', Decimal('4.1'), 9990, 9990, 'LG K10 2017 ', 0, '0.0'),
#  ('LG', 'Illusion Sky', '8 GB', '128 GB', Decimal('4.2'), 29999, 80000, 'LG Wing ', 50001, '62.50125'),
#  ('LG', 'Titan', '4 GB', '64 GB', Decimal('4.1'), 30990, 30990, 'LG V20a ', 0, '0.0'),
#  ('LG', 'Blue', '6 GB', '128 GB', Decimal('4.4'), 55000, 55000, 'LG G7+ ThinQ ', 0, '0.0'),
#  ('LG', 'Black Gold', '2 GB', '16 GB', Decimal('4.0'), 6980, 6980, 'LG K10 K420DS ', 0, '0.0'),
#  ('LG', 'Black', '3 GB', '32 GB', Decimal('4.0'), 16990, 16990, 'LG Q6 ', 0, '0.0'),
#  ('LG', 'Gold', '3 GB', '32 GB', Decimal('4.0'), 16990, 16990, 'LG Q6 ', 0, '0.0'),
#  ('LG', 'Black', '3 GB', '32 GB', Decimal('3.3'), 9990, 9990, 'LG Q7 ', 0, '0.0'),
#  ('LG', 'Black', '2 GB', '16 GB', Decimal('4.0'), 8499, 8499, 'LG X Power ', 0, '0.0'),
#  ('LG', 'Titan', '3 GB', '16 GB', Decimal('4.1'), 14250, 14250, 'LG Stylus 2 Plus ', 0, '0.0'),
#  ('Google Pixel', 'Ice', '2 GB', '32 GB', Decimal('4.3'), 29990, 29990, 'Google Pixel Nexus 5X ', 0, '0.0'),
#  ('Google Pixel', 'Carbon', '2 GB', '16 GB', Decimal('4.3'), 25990, 25990, 'Google Pixel Nexus 5X ', 0, '0.0'),
#  ('LG', 'Black', '4 GB', '64 GB', Decimal('3.9'), 19990, 19990, 'LG Q6+ ', 0, '0.0'),
#  ('LG', 'Titan', '1.5 GB', '8 GB', Decimal('4.1'), 6590, 6590, 'LG K-7 ', 0, '0.0'),
#  ('LG', 'White', '1 GB', '8 GB', Decimal('3.8'), 15999, 15999, 'LG G3 Beat ', 0, '0.0'),
#  ('LG', 'Blue', '4 GB', '64 GB', Decimal('3.9'), 19990, 19990, 'LG Q6+ ', 0, '0.0'),
#  ('LG', 'Red', '3 GB', '32 GB', Decimal('4.0'), 35990, 35990, 'LG G4 ', 0, '0.0'),
#  ('LG', 'Genuine Leather Black', '3 GB', '32 GB', Decimal('4.0'), 35990, 35990, 'LG G4 ', 0, '0.0'),
#  ('LG', 'Brown', '2 GB', '16 GB', Decimal('4.1'), 9999, 9999, 'LG Stylus 2 ', 0, '0.0'),
#  ('LG', 'Titan', '3 GB', '16 GB', Decimal('3.8'), 9990, 9990, 'LG Stylus 3 ', 0, '0.0'),
#  ('Google Pixel', 'White', '2 GB', '16 GB', Decimal('4.5'), 25400, 25400, 'Google Pixel Nexus 5X ', 0, '0.0'),
#  ('LG', 'Brown', '2 GB', '16 GB', Decimal('4.1'), 8350, 19000, 'LG Stylus 2 ', 10650, '56.05263157894736'),
#  ('LG', 'Black Titan', '1 GB', '8 GB', Decimal('3.9'), 7000, 17000, 'LG L Bello ', 10000, '58.82352941176471'),
#  ('LG', 'Titan', '1 GB', '16 GB', Decimal('3.6'), 7000, 14990, 'LG G4 Stylus 4G LTE ', 7990, '53.30220146764509'),
#  ('LG', 'Titan Silver', '2 GB', '16 GB', Decimal('3.5'), 9999, 9999, 'LG X Cam ', 0, '0.0'),
#  ('LG', 'Black', '512 MB', '4 GB', Decimal('3.9'), 6299, 6299, 'LG Optimus L3 II E425 ', 0, '0.0'),
#  ('LG', 'White', '768 MB', '4 GB', Decimal('4.0'), 13299, 13299, 'LG Optimus L7 II Dual ', 0, '0.0'),
#  ('LG', 'Pink', '4 GB', '64 GB', Decimal('4.2'), 31490, 31490, 'LG V20 ', 0, '0.0'),
#  ('LG', 'Black', '2 GB', '16 GB', Decimal('4.1'), 9000, 9000, 'LG K10 2017 ', 0, '0.0'),
#  ('LG', 'Titan', '4 GB', '32 GB', Decimal('4.0'), 22999, 22999, 'LG G5 ', 0, '0.0'),
#  ('LG', 'Platinum Grey', '3 GB', '32 GB', Decimal('3.9'), 8199, 10999, 'LG W30 ', 2800, '25.456859714519503'),
#  ('Google Pixel', 'Black', '2 GB', '16 GB', Decimal('4.5'), 12000, 29990, 'Google Pixel Nexus 5X ', 17990, '59.98666222074025'),
#  ('LG', 'Metallic Gray', '3 GB', '32 GB', Decimal('4.0'), 25999, 25999, 'LG G4 ', 0, '0.0'),
#  ('LG', 'White', '4 GB', '64 GB', Decimal('4.2'), 24998, 49999, 'LG G6 ', 25001, '50.0030000600012'),
#  ('LG', 'Blue', '4 GB', '64 GB', Decimal('4.2'), 29790, 29790, 'LG G6 ', 0, '0.0'),
#  ('LG', 'Gold', '4 GB', '32 GB', Decimal('4.0'), 25999, 25999, 'LG G5 ', 0, '0.0'),
#  ('LG', 'White', '1 GB', '4 GB', Decimal('3.7'), 14162, 14162, 'LG L 80 Dual ', 0, '0.0'),
#  ('LG', 'Black Titan', '1 GB', '8 GB', Decimal('4.1'), 13990, 13990, 'LG G3 Stylus ', 0, '0.0'),
#  ('LG', 'Moroccan Blue', '3 GB', '32 GB', Decimal('3.3'), 16790, 16790, 'LG Q7 ', 0, '0.0'),
#  ('LG', 'Lavender Violet', '3 GB', '32 GB', Decimal('3.3'), 16996, 16996, 'LG Q7 ', 0, '0.0'),
#  ('LG', 'Moroccan Blue', '4 GB', '64 GB', Decimal('3.2'), 20998, 20998, 'LG Q7+ ', 0, '0.0'),
#  ('LG', 'Lavender Violet', '4 GB', '64 GB', Decimal('3.2'), 21001, 21001, 'LG Q7+ ', 0, '0.0'),
#  ('LG', 'Black', '2 GB', '16 GB', Decimal('4.0'), 7990, 7990, 'LG X Screen K500I ', 0, '0.0'),
#  ('LG', 'Black', '4 GB', '64 GB', Decimal('3.2'), 11849, 18990, 'LG Q7+ ', 7141, '37.60400210637177'),
#  ('LG', 'Black Titan', '1 GB', '8 GB', Decimal('3.8'), 8000, 8000, 'LG Spirit ', 0, '0.0'),
#  ('LG', 'Black Gold', '1 GB', '8 GB', Decimal('3.8'), 8000, 8000, 'LG Spirit ', 0, '0.0'),
#  ('LG', 'Genuine Leather Brown', '3 GB', '32 GB', Decimal('4.0'), 30600, 30600, 'LG G4 ', 0, '0.0'),
#  ('ASUS', 'Black', '8 GB', '128 GB', Decimal('4.3'), 49999, 55999, 'ASUS ROG Phone 5 ', 6000, '10.714477044232932'),
#  ('ASUS', 'Black', '12 GB', '128 GB', Decimal('4.4'), 49999, 57999, 'ASUS ROG Phone 3 ', 8000, '13.79334126450456'),
#  ('ASUS', 'Grey', '4 GB', '64 GB', Decimal('4.3'), 15599, 15599, 'ASUS Zenfone Max Pro M1 ', 0, '0.0'),
#  ('ASUS', 'Black', '2 GB', '16 GB', Decimal('4.1'), 7999, 7999, 'ASUS Zenfone 2 Laser ZE500KL ', 0, '0.0'),
#  ('ASUS', 'Black', '8 GB', '128 GB', Decimal('4.4'), 46999, 55999, 'ASUS ROG Phone 3 ', 9000, '16.071715566349397'),
#  ('ASUS', 'Blue', '3 GB', '32 GB', Decimal('4.3'), 12999, 12999, 'ASUS ZenFone Max M2 ', 0, '0.0'),
#  ('ASUS', 'Midnight Blue', '6 GB', '128 GB', Decimal('4.5'), 36299, 36299, 'ASUS ZenFone 5Z ', 0, '0.0'),
#  ('ASUS', 'Blue', '4 GB', '64 GB', Decimal('4.3'), 15599, 15599, 'ASUS Zenfone Max Pro M1 ', 0, '0.0'),
#  ('ASUS', 'Black', '6 GB', '64 GB', Decimal('4.3'), 35999, 35999, 'ASUS 6Z ', 0, '0.0'),
#  ('ASUS', 'Black', '4 GB', '64 GB', Decimal('4.3'), 15599, 15599, 'ASUS Zenfone Max Pro M1 ', 0, '0.0'),
#  ('ASUS', 'Black', '1 GB', '8 GB', Decimal('3.9'), 5299, 5299, 'ASUS Zenfone Go 4.5 ', 0, '0.0'),
#  ('ASUS', 'Black', '4 GB', '64 GB', Decimal('4.3'), 14999, 14999, 'ASUS ZenFone Max M2 ', 0, '0.0'),
#  ('ASUS', 'Meteor Silver', '6 GB', '128 GB', Decimal('4.5'), 36299, 36299, 'ASUS ZenFone 5Z ', 0, '0.0'),
#  ('ASUS', 'Gold', '2 GB', '32 GB', Decimal('3.7'), 6999, 6999, 'ASUS Zenfone Go 5.5 ', 0, '0.0'),
#  ('ASUS', 'Gold', '2 GB', '16 GB', Decimal('3.8'), 8999, 8999, 'ASUS Zenfone Go 3rd Gen', 0, '0.0'),
#  ('ASUS', 'Red', '1 GB', '8 GB', Decimal('3.7'), 5299, 5299, 'ASUS Zenfone Go 2nd Gen', 0, '0.0'),
#  ('ASUS', 'Silver', '1 GB', '8 GB', Decimal('3.8'), 5299, 5299, 'ASUS Zenfone Go ', 0, '0.0'),
#  ('ASUS', 'Silver', '4 GB', '64 GB', Decimal('4.3'), 14999, 14999, 'ASUS ZenFone Max M2 ', 0, '0.0'),
#  ('ASUS', 'Black', '2 GB', '16 GB', Decimal('4.2'), 7199, 7199, 'ASUS ZenFone Lite L1 ', 0, '0.0'),
#  ('ASUS', 'Black', '3 GB', '32 GB', Decimal('4.3'), 12999, 12999, 'ASUS ZenFone Max M2 ', 0, '0.0'),
#  ('ASUS', 'Black', '3 GB', '32 GB', Decimal('4.1'), 10999, 10999, 'ASUS Zenfone 4 Selfie ', 0, '0.0'),
#  ('ASUS', 'Grey', '6 GB', '64 GB', Decimal('4.3'), 17999, 17999, 'ASUS Zenfone Max Pro M1 ', 0, '0.0'),
#  ('ASUS', 'Silver', '6 GB', '128 GB', Decimal('4.3'), 38999, 38999, 'ASUS 6Z ', 0, '0.0'),
#  ('ASUS', 'Silver', '1 GB', '8 GB', Decimal('3.8'), 5699, 5699, 'ASUS Zenfone Go ', 0, '0.0'),
#  ('ASUS', 'Black', '8 GB', '128 GB', Decimal('4.6'), 40999, 40999, 'ASUS ROG Phone II ', 0, '0.0'),
#  ('ASUS', 'Black', '2 GB', '16 GB', Decimal('3.8'), 8499, 8499, 'ASUS Zenfone GO ', 0, '0.0'),
#  ('ASUS', 'White', '2 GB', '16 GB', Decimal('4.0'), 6999, 6999, 'ASUS Zenfone Go 5.0 ', 0, '0.0'),
#  ('ASUS', 'Black', '12 GB', '256 GB', Decimal('4.5'), 57999, 63999, 'ASUS ROG Phone 5 ', 6000, '9.375146486663855'),
#  ('ASUS', 'Gold', '2 GB', '16 GB', Decimal('4.2'), 7199, 7199, 'ASUS ZenFone Lite L1 ', 0, '0.0'),
#  ('ASUS', 'Blue', '3 GB', '32 GB', Decimal('4.3'), 15999, 15999, 'ASUS ZenFone Max Pro M2 ', 0, '0.0'),
#  ('ASUS', 'Pink', '1 GB', '8 GB', Decimal('3.9'), 5299, 5299, 'ASUS Zenfone Go 4.5 ', 0, '0.0'),
#  ('ASUS', 'White', '1 GB', '8 GB', Decimal('3.7'), 5299, 5299, 'ASUS Zenfone Go 2nd Gen', 0, '0.0'),
#  ('ASUS', 'Gold', '2 GB', '16 GB', Decimal('3.6'), 5840, 5840, 'ASUS Zenfone Go 5.0 LTE 2nd Gen ', 0, '0.0'),
#  ('ASUS', 'Black', '12 GB', '256 GB', Decimal('4.4'), 57999, 65999, 'ASUS ROG Phone 3 ', 8000, '12.12139577872392'),
#  ('ASUS', 'Gold', '1 GB', '8 GB', Decimal('3.8'), 5699, 5699, 'ASUS Zenfone Go ', 0, '0.0'),
#  ('ASUS', 'Red', '1 GB', '8 GB', Decimal('3.8'), 6299, 6299, 'ASUS Zenfone C ', 0, '0.0'),
#  ('ASUS', 'Silver Blue', '1 GB', '8 GB', Decimal('3.8'), 5699, 5699, 'ASUS Zenfone Go ', 0, '0.0'),
#  ('ASUS', 'White', '2 GB', '16 GB', Decimal('3.7'), 4990, 4990, 'ASUS Zenfone Go 5.0 LTE ', 0, '0.0'),
#  ('ASUS', 'Black', '2 GB', '8 GB', Decimal('4.0'), 4990, 4990, 'ASUS Zenfone Go 5.0 ', 0, '0.0'),
#  ('ASUS', 'Yellow', '1 GB', '8 GB', Decimal('3.7'), 5299, 5299, 'ASUS Zenfone Go 2nd Gen', 0, '0.0'),
#  ('ASUS', 'Black', '1 GB', '8 GB', Decimal('3.8'), 6299, 6299, 'ASUS Zenfone C ', 0, '0.0'),
#  ('ASUS', 'White', '1 GB', '8 GB', Decimal('3.8'), 6299, 6299, 'ASUS Zenfone C ', 0, '0.0'),
#  ('ASUS', 'Gold', '1 GB', '8 GB', Decimal('3.8'), 4649, 4649, 'ASUS Zenfone Go ', 0, '0.0'),
#  ('ASUS', 'White', '12 GB', '256 GB', Decimal('4.5'), 57999, 63999, 'ASUS ROG Phone 5 ', 6000, '9.375146486663855'),
#  ('ASUS', 'Silver', '8 GB', '256 GB', Decimal('4.3'), 43999, 43999, 'ASUS 6Z ', 0, '0.0'),
#  ('ASUS', 'Meteor Silver', '8 GB', '256 GB', Decimal('4.5'), 43999, 43999, 'ASUS ZenFone 5Z ', 0, '0.0'),
#  ('ASUS', 'Silver', '6 GB', '64 GB', Decimal('4.3'), 35999, 35999, 'ASUS 6Z ', 0, '0.0'),
#  ('ASUS', 'Blue', '3 GB', '32 GB', Decimal('4.1'), 14499, 14499, 'ASUS Zenfone Max ZC550KL ', 0, '0.0'),
#  ('ASUS', 'Black', '2 GB', '16 GB', Decimal('4.1'), 6990, 6990, 'ASUS Zenfone Max ', 0, '0.0'),
#  ('ASUS', 'Black', '2 GB', '16 GB', Decimal('3.6'), 4999, 4999, 'ASUS Zenfone Go 5.0 LTE 2nd Gen ', 0, '0.0'),
#  ('ASUS', 'Blue', '6 GB', '64 GB', Decimal('4.3'), 17999, 17999, 'ASUS Zenfone Max Pro M1 ', 0, '0.0'),
#  ('ASUS', 'Blue', '3 GB', '32 GB', Decimal('4.3'), 13199, 13199, 'ASUS Zenfone Max Pro M1 ', 0, '0.0'),
#  ('ASUS', 'Silver', '1 GB', '8 GB', Decimal('3.6'), 4890, 4890, 'ASUS Zenfone Go 4.5 LTE ', 0, '0.0'),
#  ('ASUS', 'Silver Blue', '1 GB', '8 GB', Decimal('3.6'), 4890, 4890, 'ASUS Zenfone Go 4.5 LTE ', 0, '0.0'),
#  ('ASUS', 'Black', '2 GB', '16 GB', Decimal('4.0'), 4499, 4499, 'ASUS Zenfone Go 5.0 ', 0, '0.0'),
#  ('ASUS', 'Silver Blue', '2 GB', '32 GB', Decimal('3.8'), 7300, 7300, 'ASUS Zenfone Go ', 0, '0.0'),
#  ('ASUS', 'Blue', '2 GB', '32 GB', Decimal('3.8'), 7499, 7499, 'ASUS Zenfone Go ', 0, '0.0'),
#  ('ASUS', 'White', '8 GB', '128 GB', Decimal('4.3'), 49999, 55999, 'ASUS ROG Phone 5 ', 6000, '10.714477044232932'),
#  ('ASUS', 'Black', '4 GB', '64 GB', Decimal('4.0'), 9599, 9599, 'ASUS ZenFone Max M1 ', 0, '0.0'),
#  ('ASUS', 'Red', '1 GB', '8 GB', Decimal('3.6'), 4890, 4890, 'ASUS Zenfone Go 4.5 LTE ', 0, '0.0'),
#  ('ASUS', 'Silver', '3 GB', '32 GB', Decimal('4.3'), 12999, 12999, 'ASUS ZenFone Max M2 ', 0, '0.0'),
#  ('ASUS', 'Black', '8 GB', '128 GB', Decimal('4.3'), 26499, 83999, 'ASUS ROG ', 57500, '68.45319587137942'),
#  ('ASUS', 'Black', '3 GB', '32 GB', Decimal('4.2'), 9599, 9599, 'ASUS ZenFone Max M1 ', 0, '0.0'),
#  ('ASUS', 'Grey', '3 GB', '32 GB', Decimal('4.0'), 17999, 17999, 'ASUS Zenfone Selfie ', 0, '0.0'),
#  ('ASUS', 'Gold', '1 GB', '8 GB', Decimal('3.6'), 4880, 4880, 'ASUS Zenfone Go 4.5 LTE ', 0, '0.0'),
#  ('ASUS', 'Matte Black', '8 GB', '256 GB', Decimal('4.3'), 43999, 43999, 'ASUS 6Z ', 0, '0.0'),
#  ('ASUS', 'Black', '6 GB', '64 GB', Decimal('4.3'), 17999, 17999, 'ASUS Zenfone Max Pro M1 ', 0, '0.0'),
#  ('ASUS', 'White', '3 GB', '16 GB', Decimal('4.0'), 13999, 13999, 'ASUS Zenfone Selfie ', 0, '0.0'),
#  ('ASUS', 'Black', '3 GB', '16 GB', Decimal('4.0'), 9999, 9999, 'ASUS Zenfone Selfie ', 0, '0.0'),
#  ('ASUS', 'Grey', '3 GB', '32 GB', Decimal('4.3'), 13199, 13199, 'ASUS Zenfone Max Pro M1 ', 0, '0.0'),
#  ('ASUS', 'Gold', '3 GB', '16 GB', Decimal('4.0'), 9999, 9999, 'ASUS Zenfone Selfie ', 0, '0.0'),
#  ('ASUS', 'Gold', '3 GB', '32 GB', Decimal('4.2'), 9599, 9599, 'ASUS ZenFone Max M1 ', 0, '0.0'),
#  ('ASUS', 'Pink', '3 GB', '32 GB', Decimal('4.0'), 17999, 17999, 'ASUS Zenfone Selfie ', 0, '0.0'),
#  ('ASUS', 'Red', '2 GB', '16 GB', Decimal('3.9'), 15999, 15999, 'ASUS Zenfone Selfie ', 0, '0.0'),
#  ('ASUS', 'White', '2 GB', '16 GB', Decimal('3.9'), 15999, 15999, 'ASUS Zenfone Selfie ', 0, '0.0'),
#  ('ASUS', 'Rose Pink', '3 GB', '32 GB', Decimal('4.1'), 10999, 10999, 'ASUS Zenfone 4 Selfie ', 0, '0.0'),
#  ('ASUS', 'Blue', '4 GB', '64 GB', Decimal('4.3'), 14999, 14999, 'ASUS ZenFone Max M2 ', 0, '0.0'),
#  ('ASUS', 'Gold', '3 GB', '32 GB', Decimal('4.1'), 10999, 10999, 'ASUS Zenfone 4 Selfie ', 0, '0.0'),
#  ('ASUS', 'Titanium', '6 GB', '64 GB', Decimal('4.3'), 19999, 19999, 'ASUS ZenFone Max Pro M2 ', 0, '0.0'),
#  ('ASUS', 'Black', '8 GB', '256 GB', Decimal('4.3'), 43999, 43999, 'ASUS 6Z ', 0, '0.0'),
#  ('ASUS', 'White', '2 GB', '16 GB', Decimal('4.1'), 7499, 7499, 'ASUS Zenfone Max ', 0, '0.0'),
#  ('ASUS', 'Midnight Blue', '8 GB', '256 GB', Decimal('4.5'), 43999, 43999, 'ASUS ZenFone 5Z ', 0, '0.0'),
#  ('ASUS', 'Black', '6 GB', '128 GB', Decimal('4.3'), 38999, 38999, 'ASUS 6Z ', 0, '0.0'),
#  ('ASUS', 'Black', '2 GB', '32 GB', Decimal('4.1'), 8499, 8499, 'ASUS Zenfone Max ', 0, '0.0'),
#  ('ASUS', 'Purple', '3 GB', '16 GB', Decimal('4.0'), 13999, 13999, 'ASUS Zenfone Selfie ', 0, '0.0'),
#  ('ASUS', 'Blue', '4 GB', '64 GB', Decimal('4.3'), 17999, 17999, 'ASUS ZenFone Max Pro M2 ', 0, '0.0'),
#  ('ASUS', 'Titanium', '3 GB', '32 GB', Decimal('4.3'), 15999, 15999, 'ASUS ZenFone Max Pro M2 ', 0, '0.0'),
#  ('ASUS', 'Black', '12 GB', '512 GB', Decimal('4.6'), 62999, 62999, 'ASUS ROG Phone II ', 0, '0.0'),
#  ('ASUS', 'Black', '3 GB', '32 GB', Decimal('4.1'), 7990, 7990, 'ASUS Zenfone Max ZC550KL ', 0, '0.0'),
#  ('ASUS', 'Grey', '2 GB', '32 GB', Decimal('3.8'), 6999, 6999, 'ASUS Zenfone Go ', 0, '0.0'),
#  ('ASUS', 'Midnight Blue', '6 GB', '64 GB', Decimal('4.5'), 32999, 32999, 'ASUS ZenFone 5Z ', 0, '0.0'),
#  ('ASUS', 'Black', '3 GB', '32 GB', Decimal('4.3'), 13199, 13199, 'ASUS Zenfone Max Pro M1 ', 0, '0.0'),
#  ('ASUS', 'Blue', '6 GB', '64 GB', Decimal('4.3'), 19999, 19999, 'ASUS ZenFone Max Pro M2 ', 0, '0.0'),
#  ('ASUS', 'Gold', '2 GB', '16 GB', Decimal('3.9'), 15999, 15999, 'ASUS Zenfone Selfie ', 0, '0.0'),
#  ('ASUS', 'Titanium', '4 GB', '64 GB', Decimal('4.3'), 17999, 17999, 'ASUS ZenFone Max Pro M2 ', 0, '0.0'),
# ...
#  ('GIONEE', 'Rose Gold', '3 GB', '32 GB', Decimal('3.8'), 6600, 6600, 'GIONEE S6 ', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1349, 1599, 'Nokia 105 DS 2020', 250, '15.634771732332709'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1340, 1340, 'Nokia TA-1010/105', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1332, 1332, 'Nokia TA-1010/105', 0, '0.0'),
#  ('Nokia', 'Black', '32 MB', '2 MB', Decimal('4.1'), 1344, 1344, 'Nokia 105', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1399, 1599, 'Nokia 105 DS 2020', 200, '12.507817385866165'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.1'), 1695, 1695, 'Nokia 110 TA-1302 DS', 0, '0.0'),
#  ('Nokia', 'Black', '16 MB', '2 MB', Decimal('4.2'), 2875, 2999, 'Nokia 216 DS', 124, '4.134711570523508'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.1'), 2440, 2510, 'Nokia 150 DS 2020', 70, '2.788844621513944'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.1'), 1680, 1762, 'Nokia 110 TA-1302 DS', 82, '4.6538024971623155'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.1'), 2480, 2599, 'Nokia 150 TA-1235 DS', 119, '4.578684109272797'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1490, 1490, 'Nokia 105 DS 2020', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1349, 1349, 'Nokia 105 SS 2021', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('3.8'), 2249, 2249, 'Nokia 125 DS', 0, '0.0'),
#  ('Nokia', 'Black', '8 MB', '16 MB', Decimal('4.1'), 3429, 3445, 'Nokia 5310ds', 16, '0.46444121915820025'),
#  ('Nokia', 'Black', '16 MB', 'Expandable Upto 32 GB', Decimal('3.8'), 3886, 3886, 'Nokia 3310 DS 2020', 0, '0.0'),
#  ('Nokia', 'Fjord', '4 GB', '64 GB', Decimal('3.9'), 11999, 13999, 'Nokia 3.4', 2000, '14.286734766769055'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('3.9'), 2142, 2192, 'Nokia 125 TA-1253 DS', 50, '2.281021897810219'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.1'), 2533, 2643, 'Nokia 150 DS 2020', 110, '4.161937192584184'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.1'), 1680, 1680, 'Nokia 110 TA-1302 DS', 0, '0.0'),
#  ('Nokia', 'Black', '16 MB', 'Expandable Upto 32 GB', Decimal('3.8'), 3999, 3999, 'Nokia 3310 DS 2020', 0, '0.0'),
#  ('Nokia', 'Grey', '3 GB', '32 GB', Decimal('3.8'), 9999, 11099, 'Nokia C20 Plus ', 1100, '9.910802775024777'),
#  ('Nokia', 'Polar Night', '6 GB', '64 GB', Decimal('3.9'), 14499, 14499, 'Nokia 5.4', 0, '0.0'),
#  ('Nokia', 'Black', '16 MB', 'Expandable Upto 32 GB', Decimal('3.8'), 3974, 4179, 'Nokia 3310 DS 2020', 205, '4.905479779851639'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1149, 1149, 'Nokia TA-1174 / TA-1299', 0, '0.0'),
#  ('Nokia', 'Charcoal Grey', '3 GB', '64 GB', Decimal('4.0'), 10399, 11499, 'Nokia 2.4', 1100, '9.566049221671449'),
#  ('Nokia', 'Nordic Blue', '2 GB', '16 GB', Decimal('3.7'), 7290, 7290, 'Nokia C3 ', 0, '0.0'),
#  ('Nokia', 'Grey', '2 GB', '32 GB', Decimal('4.4'), 8999, 10499, 'Nokia C20 Plus ', 1500, '14.287074959519956'),
#  ('Nokia', 'Blue', '3 GB', '32 GB', Decimal('3.8'), 9999, 11099, 'Nokia C20 Plus ', 1100, '9.910802775024777'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('3.9'), 2349, 2349, 'Nokia 125 DS 2020', 0, '0.0'),
#  ('Nokia', 'Blue', '2 GB', '32 GB', Decimal('4.4'), 8999, 10499, 'Nokia C20 Plus ', 1500, '14.287074959519956'),
#  ('Nokia', 'Black', '8 MB', '16 MB', Decimal('4.2'), 3740, 3740, 'Nokia 5310 TA-1212 DS', 0, '0.0'),
#  ('Nokia', 'Sand', '3 GB', '32 GB', Decimal('3.8'), 9999, 9999, 'Nokia C3 ', 0, '0.0'),
#  ('Nokia', 'Dusk', '4 GB', '64 GB', Decimal('3.9'), 11999, 13999, 'Nokia 3.4', 2000, '14.286734766769055'),
#  ('Nokia', 'Charcoal', '4 GB', '64 GB', Decimal('3.9'), 11999, 13999, 'Nokia 3.4', 2000, '14.286734766769055'),
#  ('Nokia', 'Black', '16 MB', '16 MB', Decimal('4.2'), 2499, 2499, 'Nokia 216 DS 2020', 0, '0.0'),
#  ('Nokia', 'Black', '64 MB', '128 MB', Decimal('3.7'), 3162, 3299, 'Nokia 215 4G DS 2020', 137, '4.152773567747802'),
#  ('Nokia', 'Black', '64 MB', '128 MB', Decimal('3.7'), 3896, 3999, 'Nokia 225 4g ds', 103, '2.5756439109777443'),
#  ('Nokia', 'Black', '64 MB', '128 MB', Decimal('3.7'), 4399, 4399, 'Nokia 225 4G DS 2020', 0, '0.0'),
#  ('Nokia', 'Black', '16 MB', '16 MB', Decimal('4.2'), 2450, 2450, 'Nokia 216 DS 2020', 0, '0.0'),
#  ('Nokia', 'Dusk', '6 GB', '64 GB', Decimal('3.9'), 14499, 18499, 'Nokia 5.4', 4000, '21.622790421103844'),
#  ('Nokia', 'Charcoal', '2 GB', '32 GB', Decimal('4.0'), 9999, 9999, 'Nokia 2.3', 0, '0.0'),
#  ('Nokia', 'Black', '64 MB', '128 MB', Decimal('3.6'), 3220, 3220, 'Nokia 215 4G DS', 0, '0.0'),
#  ('Nokia', 'Blue', '6 GB', '128 GB', Decimal('3.8'), 56299, 56299, 'Nokia 9', 0, '0.0'),
#  ('Nokia', 'Dusk', '4 GB', '64 GB', Decimal('3.9'), 12999, 16799, 'Nokia 5.4', 3800, '22.62039407107566'),
#  ('Nokia', 'Polar Night', '4 GB', '64 GB', Decimal('3.9'), 12999, 16799, 'Nokia 5.4', 3800, '22.62039407107566'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1399, 1399, 'Nokia 105 SS 2021', 0, '0.0'),
#  ('Nokia', 'Fjord Blue', '3 GB', '64 GB', Decimal('4.0'), 10399, 11499, 'Nokia 2.4', 1100, '9.566049221671449'),
#  ('Nokia', 'Dusk Purple', '3 GB', '64 GB', Decimal('4.0'), 10399, 11499, 'Nokia 2.4', 1100, '9.566049221671449'),
#  ('Nokia', 'Nordic Blue', '3 GB', '32 GB', Decimal('3.8'), 7499, 9999, 'Nokia C3 ', 2500, '25.002500250025'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 2000, 2000, 'Nokia 150', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1400, 1400, 'Nokia 105 DS', 0, '0.0'),
#  ('Nokia', 'Black', '8 MB', 'Expandable Upto 32 GB', Decimal('4.1'), 2200, 2200, 'Nokia 215', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '8 MB', Decimal('4.2'), 1600, 1600, 'Nokia 130', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '2 MB', Decimal('4.2'), 1600, 1600, 'Nokia 130', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1900, 1900, 'Nokia 108 Dual SIM', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', 'Expandable Upto 16 GB', Decimal('4.2'), 1900, 1900, 'Nokia 107 Dual SIM', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1660, 1700, 'Nokia 105 DS', 40, '2.3529411764705883'),
#  ('Nokia', 'Sand', '2 GB', '16 GB', Decimal('3.7'), 7299, 7299, 'Nokia C3 ', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1500, 1500, 'Nokia 150/150 DS', 0, '0.0'),
#  ('Nokia', 'Black', '64 MB', '128 MB', Decimal('3.7'), 3899, 4399, 'Nokia 225 4G DS 2020', 500, '11.366219595362583'),
#  ('Nokia', 'Black', '3 GB', '32 GB', Decimal('4.1'), 10499, 10999, 'Nokia 3.2', 500, '4.545867806164196'),
#  ('Nokia', 'Black', '16 MB', 'Expandable Upto 32 GB', Decimal('3.8'), 3499, 3499, 'Nokia 3310 DS 2020', 0, '0.0'),
#  ('Nokia', 'Black', '3 GB', '32 GB', Decimal('4.3'), 13199, 13199, 'Nokia 5.1 Plus ', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '8 MB', Decimal('4.2'), 1625, 1625, 'Nokia 130', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1000, 1000, 'Nokia Ta -1010/105', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.3'), 1000, 1000, 'Nokia 105', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', 'Expandable Upto 16 GB', Decimal('4.2'), 1860, 1860, 'Nokia 107 Dual SIM', 0, '0.0'),
#  ('Nokia', 'Black', '2 GB', '16 GB', Decimal('3.8'), 9999, 9999, 'Nokia 3.2', 0, '0.0'),
#  ('Nokia', 'Black', '3 GB', '32 GB', Decimal('4.1'), 11999, 11999, 'Nokia 3.2', 0, '0.0'),
#  ('Nokia', 'Copper', '3 GB', '32 GB', Decimal('4.2'), 14927, 14927, 'Nokia 6.1', 0, '0.0'),
#  ('Nokia', 'Black', '1 GB', '8 GB', Decimal('4.0'), 6500, 6500, 'Nokia 2.1', 0, '0.0'),
#  ('Nokia', 'Matte Black', '3 GB', '16 GB', Decimal('4.1'), 12499, 12499, 'Nokia 5', 0, '0.0'),
#  ('Nokia', 'Dark Blue', '1 GB', '8 GB', Decimal('3.9'), 4800, 4800, 'Nokia 1', 0, '0.0'),
#  ('Nokia', 'Grey / Silver', '1 GB', '8 GB', Decimal('4.0'), 7739, 7739, 'Nokia 2.1', 0, '0.0'),
#  ('Nokia', 'Warm Red', '1 GB', '8 GB', Decimal('3.9'), 4672, 4672, 'Nokia 1', 0, '0.0'),
#  ('Nokia', 'Gold', '4 GB', '64 GB', Decimal('4.0'), 18300, 18300, 'Nokia 6.1', 0, '0.0'),
#  ('Nokia', 'Black', '16 MB', '16 MB', Decimal('4.1'), 3100, 3100, 'Nokia 112', 0, '0.0'),
#  ('Nokia', 'Matte Black', '3 GB', '32 GB', Decimal('3.9'), 13999, 13999, 'Nokia 6', 0, '0.0'),
#  ('Nokia', 'Copper/Black', '1 GB', '8 GB', Decimal('3.8'), 7007, 7007, 'Nokia 2', 0, '0.0'),
#  ('Nokia', 'Blue & Silver', '1 GB', '8 GB', Decimal('4.0'), 7712, 7712, 'Nokia 2.1', 0, '0.0'),
#  ('Nokia', 'Black', '2 GB', '16 GB', Decimal('3.9'), 9999, 9999, 'Nokia 3.1', 0, '0.0'),
#  ('Nokia', 'Black', '2 GB', '16 GB', Decimal('3.9'), 10000, 10000, 'Nokia 3.1', 0, '0.0'),
#  ('Nokia', 'Silver White', '2 GB', '16 GB', Decimal('3.9'), 8588, 8588, 'Nokia 3', 0, '0.0'),
#  ('Nokia', 'Black&Blue', '3 GB', '32 GB', Decimal('4.0'), 16300, 16300, 'Nokia 5.1', 0, '0.0'),
#  ('Nokia', 'Sand', '2 GB', '32 GB', Decimal('4.0'), 9999, 9999, 'Nokia 2.3', 0, '0.0'),
#  ('Nokia', 'Cyan Green', '2 GB', '32 GB', Decimal('4.0'), 9999, 9999, 'Nokia 2.3', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 2149, 2149, 'Nokia 108 Dual SIM', 0, '0.0'),
#  ('Nokia', 'Black', '64 MB', '128 MB', Decimal('3.7'), 3599, 3599, 'Nokia 215 4G DS 2020', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 2540, 2540, 'Nokia 150/150 DS', 0, '0.0'),
#  ('Nokia', 'Cyan Green', '2 GB', '32 GB', Decimal('4.0'), 8449, 8449, 'Nokia 2.3', 0, '0.0'),
#  ('Nokia', 'Black', '8 MB', '2 MB', Decimal('4.0'), 2999, 2999, 'Nokia 220', 0, '0.0'),
#  ('Nokia', 'Black', '2 GB', '16 GB', Decimal('4.0'), 8599, 8599, 'Nokia 2.2', 0, '0.0'),
#  ('Nokia', 'Gold', '3 GB', '32 GB', Decimal('4.2'), 17979, 17979, 'Nokia 6.1', 0, '0.0'),
#  ('Nokia', 'Copper', '3 GB', '16 GB', Decimal('4.1'), 15299, 15299, 'Nokia 5', 0, '0.0'),
#  ('Nokia', 'Black', '1 GB', '32 GB', Decimal('4.3'), 40699, 40699, 'Nokia Lumia 920 ', 0, '0.0'),
#  ('Nokia', 'Charcoal', '3 GB', '32 GB', Decimal('4.2'), 7088, 12799, 'Nokia 3.1 Plus ', 5711, '44.62067349011642'),
#  ('Nokia', 'Baltic', '3 GB', '32 GB', Decimal('4.2'), 10440, 10440, 'Nokia 3.1 Plus ', 0, '0.0'),
#  ('Nokia', 'White', '512 MB', 'Expandable Upto 32 GB', Decimal('3.8'), 7399, 7399, 'Nokia Asha 503 ', 0, '0.0'),
#  ('Nokia', 'Black', '16 MB', '10 MB', Decimal('3.6'), 1599, 1599, 'Nokia 110', 0, '0.0'),
#  ('Nokia', 'Black', '8 MB', 'Expandable Upto 32 GB', Decimal('4.0'), 3499, 3499, 'Nokia 225', 0, '0.0'),
#  ('Nokia', 'Black', '3 GB', '32 GB', Decimal('4.0'), 9599, 9599, 'Nokia 2.2', 0, '0.0'),
#  ('Nokia', 'Iron', '3 GB', '32 GB', Decimal('4.2'), 17979, 17979, 'Nokia 6.1', 0, '0.0'),
#  ('Nokia', 'Black', '4 MB', '4 MB', Decimal('4.2'), 1560, 1560, 'Nokia 106', 0, '0.0'),
#  ('Nokia', 'Steel', '3 GB', '32 GB', Decimal('4.0'), 9599, 9599, 'Nokia 2.2', 0, '0.0'),
#  ('Nokia', 'Yellow', '512 MB', '4 GB', Decimal('3.7'), 3400, 8400, 'Nokia 8110', 5000, '59.523809523809526'),
#  ('Nokia', 'Steel', '3 GB', '32 GB', Decimal('4.1'), 12399, 12399, 'Nokia 3.2', 0, '0.0'),
#  ('Nokia', 'Pewter / White', '1 GB', '8 GB', Decimal('3.8'), 6295, 6295, 'Nokia 2', 0, '0.0'),
#  ('Nokia', 'White', '3 GB', '32 GB', Decimal('4.3'), 13199, 13199, 'Nokia 5.1 Plus ', 0, '0.0'),
#  ('Nokia', 'Copper', '4 GB', '32 GB', Decimal('4.0'), 12999, 19999, 'Nokia 6.1', 7000, '35.00175008750438'),
#  ('Nokia', 'White', '4 GB', '32 GB', Decimal('4.0'), 17000, 17000, 'Nokia 6.1', 0, '0.0'),
#  ('Nokia', 'Tempered Blue', '2 GB', '16 GB', Decimal('3.9'), 10899, 10899, 'Nokia 3', 0, '0.0'),
#  ('Nokia', 'Matte Black', '2 GB', '16 GB', Decimal('3.9'), 5290, 5290, 'Nokia 3', 0, '0.0'),
#  ('Nokia', 'White', '3 GB', '32 GB', Decimal('4.2'), 7399, 7399, 'Nokia 3.1 Plus ', 0, '0.0'),
#  ('Nokia', 'Black', '6 GB', '128 GB', Decimal('4.3'), 29990, 29990, 'Nokia 8 Sirocco ', 0, '0.0'),
#  ('Nokia', 'Tempered Blue', '3 GB', '16 GB', Decimal('4.1'), 16199, 16199, 'Nokia 5', 0, '0.0'),
#  ('Nokia', 'Black', '16 MB', '256 MB', Decimal('4.0'), 4196, 4196, 'Nokia RM-1172 / Nokia 230 DS', 0, '0.0'),
#  ('Nokia', 'Silver', '3 GB', '32 GB', Decimal('3.9'), 7999, 7999, 'Nokia 6', 0, '0.0'),
#  ('Nokia', 'Gold', '4 GB', '32 GB', Decimal('4.0'), 9500, 9500, 'Nokia 6.1', 0, '0.0'),
#  ('Nokia', 'SAND', '6 GB', '64 GB', Decimal('3.7'), 12999, 12999, 'Nokia 5.3', 0, '0.0'),
#  ('Nokia', 'CYAN', '6 GB', '64 GB', Decimal('3.7'), 12999, 12999, 'Nokia 5.3', 0, '0.0'),
#  ('Nokia', 'White', '512 MB', '8 GB', Decimal('4.1'), 17599, 17599, 'Nokia Lumia 625 ', 0, '0.0'),
#  ('Nokia', 'Black', '3 GB', '32 GB', Decimal('4.0'), 6990, 6990, 'Nokia 3.1', 0, '0.0'),
#  ('Nokia', 'White', '3 GB', '32 GB', Decimal('4.0'), 7490, 13824, 'Nokia 3.1', 6334, '45.81886574074074'),
#  ('Nokia', 'Blue', '6 GB', '64 GB', Decimal('4.1'), 11990, 16999, 'Nokia 6.1 Plus ', 5009, '29.466439202306017'),
#  ('Nokia', 'Dark Grey', '512 MB', '140 MB', Decimal('4.0'), 5999, 6879, 'Nokia Asha 311 ', 880, '12.792557057711877'),
#  ('Nokia', 'Blue', '4 GB', '64 GB', Decimal('4.3'), 28831, 28831, 'Nokia 8.1', 0, '0.0'),
#  ('Nokia', 'Charcoal', '4 GB', '64 GB', Decimal('4.1'), 19999, 19999, 'Nokia 7.2', 0, '0.0'),
#  ('Nokia', 'Charcoal', '6 GB', '64 GB', Decimal('4.1'), 20999, 20999, 'Nokia 7.2', 0, '0.0'),
#  ('Nokia', 'Cyan Green', '6 GB', '64 GB', Decimal('4.1'), 20999, 20999, 'Nokia 7.2', 0, '0.0'),
#  ('Nokia', 'Ice', '6 GB', '64 GB', Decimal('4.1'), 20999, 20999, 'Nokia 7.2', 0, '0.0'),
#  ('Nokia', 'Ice', '4 GB', '64 GB', Decimal('4.1'), 19999, 19999, 'Nokia 7.2', 0, '0.0'),
#  ('Nokia', 'Cyan Green', '4 GB', '64 GB', Decimal('4.1'), 19999, 19999, 'Nokia 7.2', 0, '0.0'),
#  ('Nokia', 'Black', '512 MB', '4 GB', Decimal('3.7'), 3000, 8400, 'Nokia 8110', 5400, '64.28571428571429'),
#  ('Nokia', 'Silver', '3 GB', '16 GB', Decimal('4.1'), 7139, 7139, 'Nokia 5', 0, '0.0'),
#  ('Nokia', 'Gold', '3 GB', '32 GB', Decimal('4.0'), 7890, 15999, 'Nokia 5.1', 8109, '50.684417776111005'),
#  ('Nokia', 'CHARCOAL', '4 GB', '64 GB', Decimal('3.5'), 10999, 10999, 'Nokia 5.3', 0, '0.0'),
#  ('Nokia', 'Blue', '4 GB', '64 GB', Decimal('4.1'), 11199, 11199, 'Nokia 7.1', 0, '0.0'),
#  ('Nokia', 'Silver', '2 GB', '16 GB', Decimal('4.0'), 6741, 6741, 'Nokia 5', 0, '0.0'),
#  ('Nokia', 'Tempered Blue', '2 GB', '16 GB', Decimal('4.0'), 6400, 6400, 'Nokia 5', 0, '0.0'),
#  ('Nokia', 'Copper', '2 GB', '16 GB', Decimal('4.0'), 6999, 14190, 'Nokia 5', 7191, '50.676532769556026'),
#  ('Nokia', 'Steel', '2 GB', '16 GB', Decimal('3.8'), 10199, 10199, 'Nokia 3.2', 0, '0.0'),
#  ('Nokia', 'Blue', '6 GB', '128 GB', Decimal('4.3'), 22999, 35999, 'Nokia 8.1', 13000, '36.112114225395146'),
#  ('Nokia', 'Black', '512 MB', '4 GB', Decimal('3.7'), 6699, 6699, 'Nokia 8110 4G', 0, '0.0'),
#  ('Nokia', 'Bright Green', '1 GB', '4 GB', Decimal('4.2'), 9999, 9999, 'Nokia X2 Dual SIM ', 0, '0.0'),
#  ('Nokia', 'White', '4 GB', '64 GB', Decimal('4.3'), 18599, 18599, 'Nokia 6.1 Plus ', 0, '0.0'),
#  ('Nokia', 'Steel', '2 GB', '16 GB', Decimal('4.0'), 8599, 8599, 'Nokia 2.2', 0, '0.0'),
#  ('Nokia', 'CYAN', '4 GB', '64 GB', Decimal('3.5'), 11989, 11989, 'Nokia 5.3', 0, '0.0'),
#  ('Nokia', 'Black', '4 GB', '64 GB', Decimal('4.1'), 9990, 15999, 'Nokia 5.1 Plus ', 6009, '37.55859741233827'),
#  ('Nokia', 'Black', '512 MB', '4 GB', Decimal('4.0'), 10999, 10999, 'Nokia Lumia 510 ', 0, '0.0'),
#  ('Nokia', 'White & Copper', '4 GB', '64 GB', Decimal('4.3'), 15999, 15999, 'Nokia 7 Plus ', 0, '0.0'),
#  ('Nokia', 'Matte Black', '4 GB', '64 GB', Decimal('3.9'), 19499, 19499, 'Nokia 6', 0, '0.0'),
#  ('Nokia', 'Black', '6 GB', '64 GB', Decimal('4.1'), 11490, 17999, 'Nokia 6.1 Plus ', 6509, '36.16312017334296'),
#  ('Nokia', 'CHARCOAL', '6 GB', '64 GB', Decimal('3.7'), 12999, 12999, 'Nokia 5.3', 0, '0.0'),
#  ('Nokia', 'Black', '32 MB', '64 MB', Decimal('3.8'), 4300, 4300, 'Nokia Asha 206', 0, '0.0'),
#  ('Nokia', 'Black', '16 MB', 'Expandable Upto 32 GB', Decimal('4.1'), 2860, 2860, 'Nokia 222', 0, '0.0'),
#  ('Nokia', 'Blue', '4 GB', '64 GB', Decimal('4.1'), 9975, 15999, 'Nokia 5.1 Plus ', 6024, '37.6523532720795'),
#  ('Nokia', 'Ice', '4 GB', '64 GB', Decimal('4.2'), 13790, 13790, 'Nokia 6.2', 0, '0.0'),
#  ('Nokia', 'Pink Sand', '3 GB', '32 GB', Decimal('4.0'), 13699, 13699, 'Nokia 4.2', 0, '0.0'),
#  ('Nokia', 'Steel', '4 GB', '64 GB', Decimal('4.1'), 12998, 12998, 'Nokia 7.1', 0, '0.0'),
#  ('Nokia', 'Steel', '4 GB', '64 GB', Decimal('4.0'), 36999, 36999, 'Nokia 8', 0, '0.0'),
#  ...]

# %% [markdown]
# ### Task 2: Distinct Smartphone Brands Analysis
#
# This task involves retrieving distinct brand names from the smartphone sales dataset. By querying and identifying unique brand names, we gain insights into the diversity of brands available in the dataset. Understanding the range of brands and their prevalence within the dataset can aid in market analysis, identifying popular brands, and assessing their market share, which is crucial for strategic business decisions and marketing strategies in the smartphone industry.

# %%
# %%sql
# SELECT DISTINCT Brand FROM cleaned_dataset
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 17 rows affected.
# [('OPPO',),
#  ('HTC',),
#  ('IQOO',),
#  ('Google Pixel',),
#  ('LG',),
#  ('ASUS',),
#  ('realme',),
#  ('GIONEE',),
#  ('Nokia',),
#  ('Apple',),
#  ('SAMSUNG',),
#  ('Lenovo',),
#  ('Motorola',),
#  ('POCO',),
#  ('vivo',),
#  ('Xiaomi',),
#  ('Infinix',)]

# %% [markdown]
# ### Task 3: Average Selling Price of OPPO Mobile Phones
#
# This task computes the average selling price specifically for OPPO mobile phones from the dataset. Determining the average selling price provides insights into the pricing strategy of OPPO phones, aiding in understanding their competitive positioning within the smartphone market. This analysis assists in gauging the price perception of OPPO devices among consumers and guides pricing decisions or market positioning strategies for similar products.

# %%
# %%sql
# SELECT AVG(`Selling Price`) AS Avg_Selling_Price
# FROM cleaned_dataset
# WHERE Brand = "OPPO";
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 1 rows affected.
# [(Decimal('18415.1573'),)]

# %% [markdown]
# ### Task 4: Top 5 Mobile Phones by Highest Original Price
#
# This task identifies the top 5 mobile phones with the highest original prices from the dataset. This analysis provides valuable insights into the premium segment of mobile phones, showcasing the most expensive devices available. Understanding which phones command the highest prices aids in market positioning assessment, recognizing premium brands, and studying consumer preferences for high-value smartphones.

# %%
# %%sql
# SELECT DISTINCT Brand, Mobile, `Original Price`
# FROM cleaned_dataset
# ORDER BY 3 DESC
# LIMIT 5
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 5 rows affected.
# [('SAMSUNG', 'SAMSUNG Galaxy Fold 2 ', 189999),
#  ('SAMSUNG', 'SAMSUNG Galaxy Z Fold3 5G ', 179999),
#  ('Apple', 'Apple iPhone 13 Pro Max', 179900),
#  ('SAMSUNG', 'SAMSUNG Galaxy Z Fold3 5G ', 171999),
#  ('Apple', 'Apple iPhone 13 Pro Max', 169900)]

# %% [markdown]
# ### Task 5: Mobile Phones Sold Above Average Price
#
# This task identifies the brand and model of mobile phones with a selling price higher than the dataset's average selling price. Analyzing devices sold above the average price allows for the recognition of premium or higher-end smartphones. Understanding which phones are priced above the average can provide insights into consumer preferences for premium features or brands, aiding in market segmentation and targeted marketing strategies.

# %%
# %%sql
# SELECT DISTINCT Brand, Mobile
# FROM cleaned_dataset
# WHERE `Selling Price` > (SELECT AVG(`Selling Price`) FROM cleaned_dataset)
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 217 rows affected.
# [('OPPO', 'OPPO Reno6 5G'),
#  ('OPPO', 'OPPO Reno5 Pro 5G'),
#  ('OPPO', 'OPPO Reno6 Pro 5G'),
#  ('OPPO', 'OPPO Reno3 Pro'),
#  ('OPPO', 'OPPO F19 Pro+ 5G'),
#  ('OPPO', 'OPPO F5'),
#  ('OPPO', 'OPPO Reno'),
#  ('OPPO', 'OPPO Reno2 Z'),
#  ('OPPO', 'OPPO Find X'),
#  ('OPPO', 'OPPO Reno4 Pro Special Edition'),
#  ('OPPO', 'OPPO Reno4 Pro'),
#  ('OPPO', 'OPPO F1 Plus'),
#  ('OPPO', 'OPPO K3'),
#  ('OPPO', 'OPPO Reno2 F'),
#  ('OPPO', 'OPPO F3 Plus'),
#  ('OPPO', 'OPPO R1 R829'),
#  ('OPPO', 'OPPO F7'),
#  ('OPPO', 'OPPO Reno2'),
#  ('OPPO', 'OPPO R17'),
#  ('OPPO', 'OPPO Reno 10x Zoom'),
#  ('HTC', 'HTC U11+ '),
#  ('IQOO', 'IQOO 3'),
#  ('Google Pixel', 'Google Pixel 4a '),
#  ('Google Pixel', 'Google Pixel 3a XL '),
#  ('Google Pixel', 'Google Pixel 3'),
#  ('Google Pixel', 'Google Pixel 3 XL '),
#  ('Google Pixel', 'Google Pixel 3a '),
#  ('Google Pixel', 'Google Pixel XL '),
#  ('Google Pixel', 'Google Pixel 2 XL '),
#  ('Google Pixel', 'Google Pixel 2'),
#  ('Google Pixel', 'Google Pixel Quite Black'),
#  ('Google Pixel', 'Google Pixel Very Silver'),
#  ('LG', 'LG Velvet Dual Screen '),
#  ('LG', 'LG Q Stylus+ '),
#  ('LG', 'LG G7+ ThinQ '),
#  ('LG', 'LG V20 '),
#  ('LG', 'LG G8X '),
#  ('LG', 'LG V40 ThinQ '),
#  ('LG', 'LG Nexus4 E960'),
#  ('LG', 'LG G7 ThinQ '),
#  ('Google Pixel', 'Google Pixel Nexus 5X '),
#  ('LG', 'LG G5 '),
#  ('LG', 'LG Velvet '),
#  ('LG', 'LG Wing '),
#  ('LG', 'LG G Pro 2 '),
#  ('LG', 'LG V30+ '),
#  ('LG', 'LG G2 D802 '),
#  ('LG', 'LG V20a '),
#  ('LG', 'LG G4 '),
#  ('LG', 'LG G6 '),
#  ('ASUS', 'ASUS ROG Phone 5 '),
#  ('ASUS', 'ASUS ROG Phone 3 '),
#  ('ASUS', 'ASUS ZenFone 5Z '),
#  ('ASUS', 'ASUS 6Z '),
#  ('ASUS', 'ASUS ROG Phone II '),
#  ('ASUS', 'ASUS ROG '),
#  ('ASUS', 'ASUS Zenfone Zoom '),
#  ('realme', 'realme X3 SuperZoom '),
#  ('realme', 'realme X50 Pro 5G '),
#  ('realme', 'realme X3 '),
#  ('realme', 'realme GT 5G '),
#  ('realme', 'realme X50 Pro '),
#  ('realme', 'realme X7 Pro 5G '),
#  ('realme', 'realme GT Master Edition '),
#  ('realme', 'realme X2 Pro '),
#  ('realme', 'realme X2 '),
#  ('Nokia', 'Nokia 9'),
#  ('Nokia', 'Nokia Lumia 920 '),
#  ('Nokia', 'Nokia 8 Sirocco '),
#  ('Nokia', 'Nokia 8.1'),
#  ('Nokia', 'Nokia 8'),
#  ('Apple', 'Apple iPhone SE '),
#  ('Apple', 'Apple iPhone XR '),
#  ('Apple', 'Apple iPhone 12 Mini '),
#  ('Apple', 'Apple iPhone 11 '),
#  ('Apple', 'Apple iPhone 12 '),
#  ('Apple', 'Apple iPhone 12 Pro '),
#  ('Apple', 'Apple iPhone 11 Pro Max '),
#  ('Apple', 'Apple iPhone 8 Plus '),
#  ('Apple', 'Apple iPhone 11 Pro '),
#  ('Apple', 'Apple iPhone XS '),
#  ('Apple', 'Apple iPhone 8 '),
#  ('Apple', 'Apple iPhone 6 Plus '),
#  ('Apple', 'Apple iPhone XS Max '),
#  ('Apple', 'Apple iPhone 7 Plus '),
#  ('Apple', 'Apple iPhone 6s '),
#  ('Apple', 'Apple iPhone 7 '),
#  ('Apple', 'Apple iPhone 6 '),
#  ('Apple', 'Apple iPhone 6s Plus '),
#  ('Apple', 'Apple iPhone X '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Z Flip3 5G '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A72 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy F62 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A52s 5G '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S10 Lite '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A52 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S10 '),
#  ('SAMSUNG', 'SAMSUNG GALAXY M51 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note 20 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note10 Lite '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A71 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A70s '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Z Fold3 5G '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S9 Plus '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A6+ '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A70 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note 20 Ultra 5G '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S20 FE '),
#  ('SAMSUNG', 'SAMSUNG Galaxy M42 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A9 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Fold 2 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S20 Ultra '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note 9 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A50 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S10 Plus '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S6 Edge '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S21 Ultra '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A7-2017 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A8 Plus '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A80 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S21 Plus '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S21 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A7 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S20+ '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S9 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note 5 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A9 Pro '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note 10 Plus '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S8 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S20 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Alpha '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note 8 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note 3 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy A8 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note 10 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note 4 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S4 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S10e '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S7 Edge '),
#  ('SAMSUNG', 'SAMSUNG Galaxy C7 Pro '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Folder 2 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note Edge '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S6 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S8 Plus '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Mega 5.8 '),
#  ('SAMSUNG', 'SAMSUNG Galaxy Note 5 Dual '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S7 '),
#  ('SAMSUNG', 'SAMSUNG S7 Edge '),
#  ('SAMSUNG', 'SAMSUNG Galaxy S6 Edge+ '),
#  ('Lenovo', 'Lenovo Vibe Z2 Pro '),
#  ('Motorola', 'Motorola Edge 20 '),
#  ('Motorola', 'Motorola Razr 5G '),
#  ('Motorola', 'Motorola Razr '),
#  ('Motorola', 'Motorola Edge+ '),
#  ('Motorola', 'Motorola X4'),
#  ('Motorola', 'Motorola Z2 Play'),
#  ('Motorola', 'Motorola Z Play'),
#  ('Motorola', 'Motorola X 2nd Generation '),
#  ('vivo', 'vivo Y21 '),
#  ('vivo', 'vivo Y20G '),
#  ('vivo', 'vivo Y33s '),
#  ('vivo', 'vivo Y20A '),
#  ('vivo', 'vivo Y12s '),
#  ('vivo', 'vivo Y20G 2021 '),
#  ('vivo', 'vivo Y20A 2021 '),
#  ('vivo', 'vivo Y73 '),
#  ('vivo', 'vivo Y1s '),
#  ('vivo', 'vivo Y12G '),
#  ('vivo', 'vivo Y51A '),
#  ('Xiaomi', 'Xiaomi Mi 10 '),
#  ('Xiaomi', 'Xiaomi Mi 10i '),
#  ('Xiaomi', 'Xiaomi Mi 10T '),
#  ('Xiaomi', 'Xiaomi Mi 11 Lite '),
#  ('Xiaomi', 'Xiaomi Mi 11X '),
#  ('Xiaomi', 'Xiaomi MI 11X 5G '),
#  ('Xiaomi', 'Xiaomi Mi 11X Pro 5G '),
#  ('Xiaomi', 'Xiaomi Redmi K20 Pro '),
#  ('HTC', 'HTC U11'),
#  ('HTC', 'HTC U Ultra'),
#  ('HTC', 'HTC 10'),
#  ('HTC', 'HTC Desire 826 DS'),
#  ('HTC', 'HTC One E9+'),
#  ('HTC', 'HTC 826'),
#  ('HTC', 'HTC 820S'),
#  ('HTC', 'HTC Desire 820'),
#  ('HTC', 'HTC 620G'),
#  ('HTC', 'HTC One M8 '),
#  ('HTC', 'HTC Desire 816  '),
#  ('HTC', 'HTC Desire 700'),
#  ('HTC', 'HTC One 802D'),
#  ('Nokia', 'Nokia XR 20'),
#  ('POCO', 'POCO F3 GT'),
#  ('POCO', 'POCO F1'),
#  ('realme', 'realme GT Neo 2'),
#  ('realme', 'realme X7 Max'),
#  ('vivo', 'vivo V23 5G'),
#  ('vivo', 'vivo V23 Pro 5G'),
#  ('vivo', 'vivo V21 5G '),
#  ('vivo', 'vivo X70 Pro+'),
#  ('vivo', 'vivo X70 Pro '),
#  ('vivo', 'vivo X60 Pro'),
#  ('vivo', 'vivo X50 Pro'),
#  ('vivo', 'vivo X50  '),
#  ('vivo', 'vivo X21'),
#  ('vivo', 'vivo V11 Pro'),
#  ('Xiaomi', 'Xiaomi Y11T Pro'),
#  ('Xiaomi', 'Xiaomi 11i 5G'),
#  ('Xiaomi', 'Xiaomi 11i Hypercharge 5G'),
#  ('Xiaomi', 'Xiaomi 11 Lite NE'),
#  ('OPPO', 'OPPO Reno7 Pro 5G'),
#  ('Apple', 'Apple iPhone 13 '),
#  ('Apple', 'Apple iPhone 13 Pro Max'),
#  ('Apple', 'Apple iPhone 13 Pro'),
#  ('Apple', 'Apple iPhone 13 mini'),
#  ('realme', 'realme 9 Pro+ 5G'),
#  ('SAMSUNG', 'SAMSUNG Galaxy S21 SE 5G'),
#  ('SAMSUNG', 'SAMSUNG M52 5G')]

# %% [markdown]
# ### Task 6: Brand-wise Average Ratings
#
# This task lists the brands alongside their average ratings, rounded to two decimal places, from the dataset. Calculating the average rating for each brand provides insights into customer satisfaction or perception of various smartphone brands. This analysis assists in understanding brand performance, aiding in strategic decisions for improving brand image, marketing strategies, or product development based on customer feedback.

# %%
# %%sql
# SELECT BRAND, ROUND(AVG(Rating),2) AS Average_Rating
# FROM cleaned_dataset
# GROUP BY 1
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 17 rows affected.
# [('OPPO', Decimal('4.30')),
#  ('HTC', Decimal('3.97')),
#  ('IQOO', Decimal('4.40')),
#  ('Google Pixel', Decimal('4.51')),
#  ('LG', Decimal('3.98')),
#  ('ASUS', Decimal('4.08')),
#  ('realme', Decimal('4.39')),
#  ('GIONEE', Decimal('3.85')),
#  ('Nokia', Decimal('4.00')),
#  ('Apple', Decimal('4.57')),
#  ('SAMSUNG', Decimal('4.21')),
#  ('Lenovo', Decimal('3.97')),
#  ('Motorola', Decimal('4.14')),
#  ('POCO', Decimal('4.39')),
#  ('vivo', Decimal('4.39')),
#  ('Xiaomi', Decimal('4.30')),
#  ('Infinix', Decimal('4.28'))]

# %% [markdown]
# ### Task 7: Mobiles with Discount Percentage Over 20%: Brand, Memory, and Storage
#
# This task showcases the brand, memory, and storage specifications of mobile phones that have a discount percentage greater than 20%. Highlighting these details assists in recognizing devices that offer higher discounts, aiding consumers in identifying potentially lucrative deals. Understanding which phones have substantial discounts can also reveal trends in pricing strategies across different phone specifications or brands within the dataset.

# %%
# %%sql
# SELECT DISTINCT Brand, Memory, Storage
# FROM cleaned_dataset
# WHERE discount_percentage > 20
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 86 rows affected.
# [('OPPO', '4 GB', '64 GB'),
#  ('OPPO', '6 GB', '128 GB'),
#  ('OPPO', '8 GB', '128 GB'),
#  ('OPPO', '8 GB', '256 GB'),
#  ('OPPO', '2 GB', '32 GB'),
#  ('OPPO', '4 GB', '128 GB'),
#  ('OPPO', '6 GB', '64 GB'),
#  ('OPPO', '3 GB', '32 GB'),
#  ('OPPO', '3 GB', '64 GB'),
#  ('OPPO', '1 GB', '16 GB'),
#  ('LG', '3 GB', '64 GB'),
#  ('LG', '2 GB', '16 GB'),
#  ('LG', '3 GB', '32 GB'),
#  ('LG', '1 GB', '8 GB'),
#  ('LG', '6 GB', '128 GB'),
#  ('LG', '4 GB', '128 GB'),
#  ('LG', '4 GB', '64 GB'),
#  ('LG', '8 GB', '128 GB'),
#  ('LG', '1 GB', '16 GB'),
#  ('Google Pixel', '2 GB', '16 GB'),
#  ('ASUS', '8 GB', '128 GB'),
#  ('realme', '6 GB', '128 GB'),
#  ('realme', '3 GB', '32 GB'),
#  ('realme', '4 GB', '64 GB'),
#  ('realme', '3 GB', '64 GB'),
#  ('GIONEE', '2 GB', '32 GB'),
#  ('GIONEE', '3 GB', '32 GB'),
#  ('GIONEE', '1 GB', '16 GB'),
#  ('GIONEE', '512 MB', '4 GB'),
#  ('GIONEE', '8 MB', '16 MB'),
#  ('GIONEE', '3 GB', '16 GB'),
#  ('GIONEE', '2 GB', '16 GB'),
#  ('GIONEE', '3 GB', '64 GB'),
#  ('GIONEE', '1 GB', '8 GB'),
#  ('Nokia', '6 GB', '64 GB'),
#  ('Nokia', '4 GB', '64 GB'),
#  ('Nokia', '3 GB', '32 GB'),
#  ('Nokia', '512 MB', '4 GB'),
#  ('Nokia', '4 GB', '32 GB'),
#  ('Nokia', '2 GB', '16 GB'),
#  ('Nokia', '6 GB', '128 GB'),
#  ('Apple', '4GB', '256 GB'),
#  ('Apple', '2 GB', '32 GB'),
#  ('Apple', '4 GB', '256 GB'),
#  ('Apple', '4 GB', '64 GB'),
#  ('Apple', '4GB', '64 GB'),
#  ('SAMSUNG', '8 GB', '128 GB'),
#  ('SAMSUNG', '6 GB', '128 GB'),
#  ('SAMSUNG', '6 GB', '64 GB'),
#  ('SAMSUNG', '4 GB', '128 GB'),
#  ('SAMSUNG', '8 GB', '256 GB'),
#  ('SAMSUNG', '12 GB', '256 GB'),
#  ('SAMSUNG', '4 GB', '64 GB'),
#  ('SAMSUNG', '2 GB', '16 GB'),
#  ('SAMSUNG', '4 GB', '32 GB'),
#  ('SAMSUNG', '1 GB', '8 GB'),
#  ('Lenovo', '4 GB', '64 GB'),
#  ('Lenovo', '3 GB', '32 GB'),
#  ('Lenovo', '1 GB', '16 GB'),
#  ('Lenovo', '2 GB', '16 GB'),
#  ('Lenovo', '3 GB', '64 GB'),
#  ('Motorola', '4 GB', '64 GB'),
#  ('Motorola', '8 GB', '256 GB'),
#  ('Motorola', '6 GB', '128 GB'),
#  ('Motorola', '4 GB', '128 GB'),
#  ('Motorola', '2 GB', '32 GB'),
#  ('Motorola', '12 GB', '256 GB'),
#  ('Motorola', '6 GB', '64 GB'),
#  ('Motorola', '4 GB', '32 GB'),
#  ('Motorola', '2 GB', '16 GB'),
#  ('POCO', '6 GB', '128 GB'),
#  ('POCO', '3 GB', '32 GB'),
#  ('vivo', '4 GB', '128 GB'),
#  ('vivo', '6 GB', '64 GB'),
#  ('vivo', '4 GB', '64 GB'),
#  ('vivo', '12 GB', '256 GB'),
#  ('vivo', '8 GB', '256 GB'),
#  ('vivo', '8 GB', '128 GB'),
#  ('Xiaomi', '6 GB', '128 GB'),
#  ('Xiaomi', '4 GB', '64 GB'),
#  ('POCO', '4 GB', '64 GB'),
#  ('POCO', '6 GB', '64 GB'),
#  ('Infinix', '4 GB', '64 GB'),
#  ('Infinix', '6 GB', '64 GB'),
#  ('Infinix', '4 GB', '128 GB'),
#  ('SAMSUNG', '2 GB', '32 GB')]

# %% [markdown]
# ### Task 8: Brand with Most Distinct Models
#
# This task identifies the brand with the highest number of distinct models within the dataset. Analyzing the brand with the maximum variety of models provides insights into the brand's product diversity and market presence. Understanding which brand offers a wider range of models can indicate their market competitiveness, product portfolio strength, and potential customer reach.

# %%
# %%sql
# SELECT Brand, COUNT(DISTINCT Mobile) AS Num_Models
# FROM cleaned_dataset
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 1
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 1 rows affected.
# [('SAMSUNG', 192)]

# %% [markdown]
# ### Task 9: Top 3 Brands by Highest Average Discount Percentage
#
# This task lists the top three brands with the highest average discount percentages from the dataset. Analyzing brands with the highest average discounts provides insights into their pricing strategies and their focus on offering discounts. Understanding which brands consistently provide higher discounts helps identify market trends, competitive pricing strategies, and consumer perception regarding pricing and offers within the smartphone market.

# %%
# %%sql
# SELECT Brand, AVG(discount_percentage)
# FROM cleaned_dataset
# GROUP BY 1
# ORDER BY 2 DESC
# LIMIT 3
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 3 rows affected.
# [('POCO', 14.543372004409704),
#  ('Motorola', 12.558436794893145),
#  ('IQOO', 9.065626593831855)]

# %% [markdown]
# ### Task 10: Total Mobiles per Memory-Storage Combination
#
# This task calculates the total count of mobiles available for each unique memory-storage combination within the dataset. Analyzing the count of mobiles per memory-storage configuration provides insights into the popularity or availability of various storage options across different memory capacities. Understanding the distribution of mobiles based on memory and storage combinations aids in identifying popular configurations and market trends, assisting manufacturers in product planning and inventory management strategies.

# %%
# %%sql
# SELECT Memory, Storage, COUNT(*)
# FROM cleaned_dataset
# GROUP BY 1,2
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 81 rows affected.
# [('4 GB', '64 GB', 511),
#  ('6 GB', '128 GB', 300),
#  ('3 GB', '32 GB', 331),
#  ('8 GB', '128 GB', 240),
#  ('2 GB', '32 GB', 124),
#  ('4 GB', '128 GB', 102),
#  ('12 GB', '256 GB', 47),
#  ('6 GB', '256 GB', 7),
#  ('8 GB', '256 GB', 71),
#  ('6 GB', '64 GB', 128),
#  ('3 GB', '64 GB', 48),
#  ('2 GB', '16 GB', 193),
#  ('4 GB', '32 GB', 71),
#  ('3 GB', '16 GB', 49),
#  ('1 GB', '16 GB', 57),
#  ('1 GB', '8 GB', 107),
#  ('1 GB', '4 GB', 13),
#  ('512 MB', '4 GB', 37),
#  ('1.5 GB', '8 GB', 20),
#  ('768 MB', '4 GB', 6),
#  ('12 GB', '128 GB', 3),
#  ('2 GB', '8 GB', 5),
#  ('12 GB', '512 GB', 4),
#  ('8 MB', '16 MB', 6),
#  ('64 MB', '128 MB', 11),
#  ('8 GB', '2 MB', 1),
#  ('4 MB', '4 MB', 27),
#  ('32 MB', '2 MB', 8),
#  ('16 MB', '2 MB', 2),
#  ('16 MB', 'Expandable Upto 32 GB', 5),
#  ('16 MB', '16 MB', 3),
#  ('8 MB', 'Expandable Upto 32 GB', 2),
#  ('4 MB', '8 MB', 2),
#  ('4 MB', '2 MB', 6),
#  ('4 MB', 'Expandable Upto 16 GB', 2),
#  ('8 MB', '2 MB', 1),
#  ('1 GB', '32 GB', 3),
#  ('512 MB', 'Expandable Upto 32 GB', 1),
#  ('16 MB', '10 MB', 1),
#  ('16 MB', '256 MB', 1),
#  ('512 MB', '8 GB', 1),
#  ('512 MB', '140 MB', 1),
#  ('32 MB', '64 MB', 2),
#  ('64 MB', 'Expandable Upto 32 GB', 2),
#  ('512 MB', '256 MB', 1),
#  ('2 GB', '64 GB', 14),
#  ('4GB', '128 GB', 23),
#  ('3 GB', '128 GB', 12),
#  ('2 GB', '128 GB', 13),
#  ('4GB', '64 GB', 27),
#  ('4GB', '256 GB', 35),
#  ('2 GB', '256 GB', 10),
#  ('6 GB', '512 GB', 3),
#  ('3 GB', '256 GB', 18),
#  ('4GB', '512 GB', 15),
#  ('4 GB', '512 GB', 6),
#  ('4 GB', '256 GB', 7),
#  ('1 GB', '64 GB', 6),
#  ('1 GB', '128 GB', 5),
#  ('8 GB', '512 GB', 7),
#  ('153 MB', '153 MB', 1),
#  ('128 MB', '2 MB', 1),
#  ('512 MB', '512 MB', 2),
#  ('512 MB', '2 MB', 1),
#  ('2 MB', '2 MB', 2),
#  ('32 MB', 'Expandable Upto 16 GB', 4),
#  ('10 MB', '2 MB', 3),
#  ('12 GB', '1 TB', 1),
#  ('46 MB', '64 MB', 1),
#  ('46 MB', '2 MB', 1),
#  ('1.5 GB', '16 GB', 9),
#  ('16 GB', '512 GB', 1),
#  ('100 MB', '100 MB', 1),
#  ('64 MB', '100 MB', 1),
#  ('30 MB', 'Expandable Upto 16 GB', 1),
#  ('512 MB', '16 GB', 2),
#  ('6 GB', '129 GB', 1),
#  ('6 GB', '130 GB', 1),
#  ('8 GB', '129 GB', 2),
#  ('8 GB', '130 GB', 1),
#  ('4GB', '1 TB', 5)]

# %% [markdown]
# ### Task 11: Brand and Storage-wise Average Selling Price
#
# This task calculates the average selling price for each brand and storage combination, rounding the results to the nearest integer. Displaying the brand, storage, and their respective average selling prices provides insights into the pricing strategies of different brands across various storage options. Understanding the average selling price for each brand and storage combination aids in identifying price trends, evaluating competitive pricing strategies, and informing consumer price preferences within specific storage capacities offered by different brands.

# %%
# %%sql
# SELECT Brand, Storage, ROUND(AVG(`Selling Price`)) AS Avg_Selling_Price
# FROM cleaned_dataset
# GROUP BY 1,2
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 117 rows affected.
# [('OPPO', '64 GB', Decimal('16557')),
#  ('OPPO', '128 GB', Decimal('20680')),
#  ('OPPO', '32 GB', Decimal('11919')),
#  ('OPPO', '256 GB', Decimal('34906')),
#  ('OPPO', '16 GB', Decimal('11377')),
#  ('HTC', '128 GB', Decimal('43993')),
#  ('HTC', '32 GB', Decimal('37574')),
#  ('IQOO', '128 GB', Decimal('34990')),
#  ('IQOO', '256 GB', Decimal('38657')),
#  ('Google Pixel', '128 GB', Decimal('76000')),
#  ('Google Pixel', '64 GB', Decimal('62909')),
#  ('Google Pixel', '32 GB', Decimal('43495')),
#  ('LG', '32 GB', Decimal('19695')),
#  ('LG', '128 GB', Decimal('34931')),
#  ('LG', '64 GB', Decimal('20250')),
#  ('LG', '8 GB', Decimal('10290')),
#  ('LG', '16 GB', Decimal('12392')),
#  ('Google Pixel', '16 GB', Decimal('22345')),
#  ('LG', '4 GB', Decimal('10925')),
#  ('ASUS', '128 GB', Decimal('41190')),
#  ('ASUS', '64 GB', Decimal('20799')),
#  ('ASUS', '16 GB', Decimal('9084')),
#  ('ASUS', '32 GB', Decimal('11326')),
#  ('ASUS', '8 GB', Decimal('5388')),
#  ('ASUS', '256 GB', Decimal('49249')),
#  ('ASUS', '512 GB', Decimal('62999')),
#  ('realme', '64 GB', Decimal('12358')),
#  ('realme', '32 GB', Decimal('8698')),
#  ('realme', '128 GB', Decimal('19718')),
#  ('realme', '256 GB', Decimal('33408')),
#  ('realme', '16 GB', Decimal('6499')),
#  ('GIONEE', '32 GB', Decimal('8371')),
#  ('GIONEE', '16 GB', Decimal('6520')),
#  ('GIONEE', '64 GB', Decimal('10725')),
#  ('GIONEE', '16 MB', Decimal('1572')),
#  ('GIONEE', '128 MB', Decimal('2820')),
#  ('GIONEE', '4 GB', Decimal('5103')),
#  ('GIONEE', '8 GB', Decimal('4767')),
#  ('GIONEE', '2 MB', Decimal('4790')),
#  ('Nokia', '4 MB', Decimal('1732')),
#  ('Nokia', '2 MB', Decimal('2205')),
#  ('Nokia', '16 MB', Decimal('3044')),
#  ('Nokia', 'Expandable Upto 32 GB', Decimal('3861')),
#  ('Nokia', '64 GB', Decimal('16915')),
#  ('Nokia', '32 GB', Decimal('11757')),
#  ('Nokia', '16 GB', Decimal('9027')),
#  ('Nokia', '128 MB', Decimal('3696')),
#  ('Nokia', '128 GB', Decimal('35655')),
#  ('Nokia', '8 MB', Decimal('1613')),
#  ('Nokia', 'Expandable Upto 16 GB', Decimal('1880')),
#  ('Nokia', '8 GB', Decimal('7791')),
#  ('Nokia', '10 MB', Decimal('1599')),
#  ('Nokia', '4 GB', Decimal('7015')),
#  ('Nokia', '256 MB', Decimal('6598')),
#  ('Nokia', '140 MB', Decimal('5999')),
#  ('Nokia', '64 MB', Decimal('3545')),
#  ('Apple', '64 GB', Decimal('60585')),
#  ('Apple', '128 GB', Decimal('63414')),
#  ('Apple', '256 GB', Decimal('89607')),
#  ('Apple', '512 GB', Decimal('142579')),
#  ('Apple', '16 GB', Decimal('46652')),
#  ('Apple', '32 GB', Decimal('30367')),
#  ('SAMSUNG', '128 GB', Decimal('31016')),
#  ('SAMSUNG', '64 GB', Decimal('22210')),
#  ('SAMSUNG', '32 GB', Decimal('19513')),
#  ('SAMSUNG', '2 MB', Decimal('2399')),
#  ('SAMSUNG', '256 GB', Decimal('83809')),
#  ('SAMSUNG', '512 GB', Decimal('86172')),
#  ('SAMSUNG', '16 GB', Decimal('12999')),
#  ('SAMSUNG', '153 MB', Decimal('1549')),
#  ('SAMSUNG', '512 MB', Decimal('1700')),
#  ('SAMSUNG', '8 GB', Decimal('8691')),
#  ('SAMSUNG', 'Expandable Upto 16 GB', Decimal('3053')),
#  ('SAMSUNG', '1 TB', Decimal('117990')),
#  ('SAMSUNG', '64 MB', Decimal('3200')),
#  ('SAMSUNG', '4 GB', Decimal('5315')),
#  ('SAMSUNG', '128 MB', Decimal('3445')),
#  ('SAMSUNG', '100 MB', Decimal('2724')),
#  ('Lenovo', '16 GB', Decimal('8092')),
#  ('Lenovo', '32 GB', Decimal('11158')),
#  ('Lenovo', '8 GB', Decimal('8297')),
#  ('Lenovo', '512 MB', Decimal('5499')),
#  ('Lenovo', '64 GB', Decimal('12921')),
#  ('Lenovo', '4 GB', Decimal('10598')),
#  ('Lenovo', '128 GB', Decimal('18999')),
#  ('Motorola', '64 GB', Decimal('13727')),
#  ('Motorola', '128 GB', Decimal('25055')),
#  ('Motorola', '16 GB', Decimal('10325')),
#  ('Motorola', '32 GB', Decimal('13873')),
#  ('Motorola', '256 GB', Decimal('77499')),
#  ('Motorola', '8 GB', Decimal('9332')),
#  ('POCO', '128 GB', Decimal('18968')),
#  ('POCO', '64 GB', Decimal('13120')),
#  ('POCO', '32 GB', Decimal('7999')),
#  ('vivo', '128 GB', Decimal('22311')),
#  ('vivo', '256 GB', Decimal('34738')),
#  ('vivo', '32 GB', Decimal('21202')),
#  ('vivo', '64 GB', Decimal('20834')),
#  ('vivo', '16 GB', Decimal('14657')),
#  ('Xiaomi', '256 GB', Decimal('41970')),
#  ('Xiaomi', '128 GB', Decimal('23568')),
#  ('Xiaomi', '64 GB', Decimal('12929')),
#  ('Xiaomi', '16 GB', Decimal('7249')),
#  ('Xiaomi', '32 GB', Decimal('8940')),
#  ('HTC', '64 GB', Decimal('62990')),
#  ('HTC', '16 GB', Decimal('24564')),
#  ('HTC', '8 GB', Decimal('16931')),
#  ('HTC', '4 GB', Decimal('14130')),
#  ('POCO', '256 GB', Decimal('27999')),
#  ('Xiaomi', '129 GB', Decimal('22427')),
#  ('Xiaomi', '130 GB', Decimal('22550')),
#  ('Infinix', '32 GB', Decimal('8848')),
#  ('Infinix', '64 GB', Decimal('11884')),
#  ('Infinix', '128 GB', Decimal('14749')),
#  ('Infinix', '256 GB', Decimal('16999')),
#  ('Infinix', '16 GB', Decimal('7199')),
#  ('Apple', '1 TB', Decimal('177900'))]

# %% [markdown]
# ### Task 12: Brand-wise Ratio of Original Price to Selling Price
#
# This task computes the ratio of the sum of original prices to the sum of selling prices for each brand, rounding the calculated ratio to two decimal places. Displaying the brand alongside this ratio provides insights into the pricing strategies and potential profit margins for each brand. Understanding this ratio can indicate how brands price their smartphones concerning their manufacturing costs, market positioning, and potential profit margins in relation to the selling price.

# %%
# %%sql
# SELECT Brand, ROUND(SUM(`Original Price`)/SUM(`Selling Price`), 2) AS Price_Ratio
# FROM cleaned_dataset
# GROUP BY 1
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 17 rows affected.
# [('OPPO', Decimal('1.11')),
#  ('HTC', Decimal('1.00')),
#  ('IQOO', Decimal('1.10')),
#  ('Google Pixel', Decimal('1.01')),
#  ('LG', Decimal('1.16')),
#  ('ASUS', Decimal('1.05')),
#  ('realme', Decimal('1.09')),
#  ('GIONEE', Decimal('1.10')),
#  ('Nokia', Decimal('1.09')),
#  ('Apple', Decimal('1.05')),
#  ('SAMSUNG', Decimal('1.11')),
#  ('Lenovo', Decimal('1.03')),
#  ('Motorola', Decimal('1.27')),
#  ('POCO', Decimal('1.16')),
#  ('vivo', Decimal('1.06')),
#  ('Xiaomi', Decimal('1.05')),
#  ('Infinix', Decimal('1.08'))]

# %% [markdown]
# ### Task 13: Brands Ranked by Model Count and Top 2 Models by Selling Price
#
# This task ranks brands based on the total count of models they offer and displays the top two models with the highest selling prices for each brand. The query utilizes window functions to rank models within each brand by selling price, enabling the extraction of the top 2 models based on their selling prices. This analysis provides insights into brand diversity in terms of model count and highlights the premium models with the highest selling prices within each brand, aiding in understanding brand positioning and product hierarchy based on pricing.

# %%
# %%sql
#
# WITH RankedBrands AS (
#     SELECT Brand, Mobile, `Selling Price`,
#            RANK() OVER (PARTITION BY Brand ORDER BY `Selling Price` DESC) as `Rank`
#     FROM cleaned_dataset
# )
#
# SELECT Brand, Mobile, `Selling Price` FROM (
#     SELECT DISTINCT Brand, Mobile, `Selling Price`, `Rank`
#     FROM RankedBrands
# ) AS DistinctRankedBrands
# WHERE `Rank` <= 2
# ORDER BY Brand, `Rank`;
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 34 rows affected.
# [('Apple', 'Apple iPhone 13 Pro Max', 179900),
#  ('ASUS', 'ASUS ROG Phone II ', 62999),
#  ('ASUS', 'ASUS ROG Phone 5 ', 57999),
#  ('ASUS', 'ASUS ROG Phone 3 ', 57999),
#  ('GIONEE', 'GIONEE A1 ', 21499),
#  ('GIONEE', 'GIONEE A1 Plus ', 16499),
#  ('Google Pixel', 'Google Pixel 3 XL ', 92000),
#  ('HTC', 'HTC U Ultra', 62990),
#  ('Infinix', 'Infinix Zero 5 Pro', 19999),
#  ('Infinix', 'Infinix Zero 8i', 18999),
#  ('IQOO', 'IQOO 3', 39990),
#  ('IQOO', 'IQOO 3', 37990),
#  ('Lenovo', 'Lenovo Vibe Z2 Pro ', 29999),
#  ('Lenovo', 'Lenovo Z2 Plus ', 19999),
#  ('Lenovo', 'Lenovo S560 ', 19999),
#  ('LG', 'LG V40 ThinQ ', 60000),
#  ('LG', 'LG G7+ ThinQ ', 55000),
#  ('Motorola', 'Motorola Razr 5G ', 89999),
#  ('Motorola', 'Motorola Razr ', 74999),
#  ('Nokia', 'Nokia 9', 56299),
#  ('Nokia', 'Nokia XR 20', 46988),
#  ('OPPO', 'OPPO Find X', 60990),
#  ('POCO', 'POCO F3 GT', 30999),
#  ('POCO', 'POCO F1', 30999),
#  ('realme', 'realme X50 Pro 5G ', 47999),
#  ('realme', 'realme X50 Pro ', 47999),
#  ('SAMSUNG', 'SAMSUNG Galaxy Z Fold3 5G ', 157999),
#  ('SAMSUNG', 'SAMSUNG Galaxy Z Fold3 5G ', 149999),
#  ('SAMSUNG', 'SAMSUNG Galaxy Fold 2 ', 149999),
#  ('vivo', 'vivo X70 Pro+', 79990),
#  ('vivo', 'vivo X60 Pro', 54990),
#  ('vivo', 'vivo X50 Pro', 54990),
#  ('Xiaomi', 'Xiaomi Mi 10 ', 54999),
#  ('Xiaomi', 'Xiaomi Mi 10 ', 45871)]

# %% [markdown]
# ### Task 14: Top Selling Price Models by Brand with Rating Above 4.4
#
# This task identifies the models with the highest selling price for each brand that has at least one model with a rating above 4.4. The query filters models with ratings above 4.4 and retrieves the highest selling price for each brand meeting this criterion. Displaying the brand, model, and respective selling price aids in recognizing premium models with high selling prices and superior ratings within each brand, facilitating an understanding of top-rated offerings with premium pricing across different brands.

# %%
# %%sql
# SELECT DISTINCT Brand, Mobile, `Selling Price`
# FROM cleaned_dataset as cd1
# WHERE Rating > 4.4
# AND `Selling Price` = (
#     SELECT MAX(`Selling Price`)
#     FROM cleaned_dataset cd2
#     WHERE cd1.Brand = cd2.Brand
# )
# ORDER BY Brand, `Selling Price` DESC;
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 6 rows affected.
# [('Apple', 'Apple iPhone 13 Pro Max', 179900),
#  ('ASUS', 'ASUS ROG Phone II ', 62999),
#  ('Google Pixel', 'Google Pixel 3 XL ', 92000),
#  ('OPPO', 'OPPO Find X', 60990),
#  ('POCO', 'POCO F1', 30999),
#  ('vivo', 'vivo X70 Pro+', 79990)]

# %% [markdown]
# ### Task 15: Brand Rating Categorization based on Average Ratings
#
# This task calculates the average rating for each brand and categorizes brands into 'Excellent', 'Good', or 'Average' based on their average ratings. The query uses a CASE statement to assign categories depending on average ratings (≥ 4.5, ≥ 4.0 and < 4.5, < 4.0). Displaying the brand names, their average ratings, and respective categories enables the segmentation of brands based on their performance in terms of average ratings, allowing insights into brand reputation and quality perception among customers.

# %%
# %%sql
# SELECT Brand, AVG(Rating) as AvgRating,
# CASE
#     WHEN AVG(Rating) >= 4.5 THEN 'Excellent'
#     WHEN AVG(Rating) >= 4.0 THEN 'Good'
#     ELSE 'Average'
# END
# FROM cleaned_dataset
# GROUP BY 1
# Out:
#  * mysql+pymysql://b31eec63:***@localhost/b31eec63
# 17 rows affected.
# [('OPPO', Decimal('4.29718'), 'Good'),
#  ('HTC', Decimal('3.96909'), 'Average'),
#  ('IQOO', Decimal('4.40000'), 'Good'),
#  ('Google Pixel', Decimal('4.50690'), 'Excellent'),
#  ('LG', Decimal('3.98163'), 'Average'),
#  ('ASUS', Decimal('4.08091'), 'Good'),
#  ('realme', Decimal('4.39384'), 'Good'),
#  ('GIONEE', Decimal('3.85000'), 'Average'),
#  ('Nokia', Decimal('4.00437'), 'Good'),
#  ('Apple', Decimal('4.56654'), 'Excellent'),
#  ('SAMSUNG', Decimal('4.20847'), 'Good'),
#  ('Lenovo', Decimal('3.97069'), 'Average'),
#  ('Motorola', Decimal('4.14216'), 'Good'),
#  ('POCO', Decimal('4.38767'), 'Good'),
#  ('vivo', Decimal('4.39298'), 'Good'),
#  ('Xiaomi', Decimal('4.30471'), 'Good'),
#  ('Infinix', Decimal('4.27600'), 'Good')]
